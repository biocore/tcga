# %%
import os, numpy, warnings
import pandas as pd

# %%
os.environ['R_HOME'] = '/home/gdpoore/anaconda3/envs/tcgaAnalysisPythonR/lib/R'
warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format = 'retina'

# %%
# %reload_ext rpy2.ipython

# %%
# %%R
#
# require(ggplot2)
# require(snm)
# require(limma)
# require(edgeR)
# require(dplyr)
# require(edgeR)
# require(pvca)
# require(lme4)
# require(ggsci)
# require(cowplot)
# require(doMC)
# require(splitstackshape)
#
# numCores <- detectCores()
# registerDoMC(cores=numCores)

# %%
# %%R
# load("snmCfdnaShogunAndMetadata_Dec2_Final.RData")
# load("snmKrakenAndMetadataFiltered_Dec2_Final.RData")

# %%
# %%R
# # Load dependencies
# require(devtools)
# require(doMC)
# require(tibble)
# require(gbm)
# require(splitstackshape)
# require(reshape2)
# require(ggpubr)
# require(caret) # for model building
# require(pROC) # for AUC calculations
# require(purrr) # for functional programming using map()
# require(dplyr) # for data manipulation
# require(doMC) # for parallel computing
# require(gbm) # for machine learning
# require(tibble) # for df operations
# require(cowplot) # for plotting
# require(PRROC) # for precision-recall curves
# require(MLmetrics) # for multi-class learning
# require(caret) # for machine learning
#
# defaultGBMGrid <-  expand.grid(interaction.depth = seq(1,3),
#                                n.trees = floor((1:3) * 50),
#                                shrinkage = 0.1,
#                                n.minobsinnode = 5)
# customGBMGrid <-  expand.grid(interaction.depth = seq(1,3),
#                               n.trees = floor((1:3) * 50),
#                               shrinkage = 0.1,
#                               n.minobsinnode = 1)
# numKFold <- 4
# numResampleIter <- 1
#
# ml2DTs <- function(snmData,
#                    classOfInterest = "Lung Adenocarcinoma",
#                    cutPoint = 0.5,
#                    samplingSize = 20,
#                    caretTuneGrid = defaultGBMGrid){
#
#   metaTmp1 <- droplevels(metadataPSMatchedDPQCFiltered[(metadataPSMatchedDPQCFiltered$disease_type_consol %in% c("PRAD",
#                                                                                                              "SKCM",
#                                                                                                              "NSCLC")),])
#   tmp <- metaTmp1
#   tmp$disease_type_consol <- factor(ifelse(metaTmp1$disease_type_consol == classOfInterest, yes = classOfInterest, no = "Other"))
#   metadataSimSampled <- as.data.frame(stratified(tmp,
#                                                  group = "disease_type_consol",
#                                                  size = samplingSize,
#                                                  keep.rownames = TRUE,
#                                                  replace = FALSE,
#                                                  bothSets = FALSE))
#   rownames(metadataSimSampled) <- metadataSimSampled$rn
#   mlDataY <- metadataSimSampled
#   mlDataX <- snmData[rownames(mlDataY),]
#
#   set.seed(42)
#   index <- createDataPartition(mlDataY$disease_type_consol, p = 0.7, list = FALSE)
#   trainX <- mlDataX[index,]
#   trainY <- mlDataY[index,]$disease_type_consol
#   testX <- mlDataX[-index,]
#   testY <- mlDataY[-index,]$disease_type_consol
#   # print(testY)
#
#   refactoredTrainY <- factor(gsub('([[:punct:]])|\\s+','',trainY))
#   refactoredTestY <- factor(gsub('([[:punct:]])|\\s+','',testY))
#
#   set.seed(42)
#   ctrl <- trainControl(method = "repeatedcv",
#                        number = numKFold,
#                        repeats = numResampleIter,
#                        sampling = "up",
#                        summaryFunction = twoClassSummary,
#                        classProbs = TRUE,
#                        verboseIter = TRUE,
#                        savePredictions = TRUE,
#                        allowParallel=TRUE)
#
#   mlModel <- train(x = trainX,
#                    y = refactoredTrainY,
#                    method = "gbm",
#                    preProcess = c("scale","center"),
#                    trControl = ctrl,
#                    verbose = TRUE,
#                    metric = "ROC",
#                    tuneGrid = customGBMGrid)
#
#   positiveClass <- gsub(" ","", classOfInterest)
#   negativeClass <- "Other"
#
#   predProbs <- as.numeric(predict(mlModel, newdata = testX, type = "prob")[,positiveClass])
#   fg <- predProbs[refactoredTestY == positiveClass]
#   bg <- predProbs[refactoredTestY == negativeClass]
#
#   prroc_roc <- roc.curve(scores.class0 = fg, scores.class1 = bg, curve = T)
#   prroc_pr <- pr.curve(scores.class0 = fg, scores.class1 = bg, curve = T, rand.compute=T)
#
#   # par(mfrow = c(1,2))
#   plot(prroc_roc)
#   plot(prroc_pr)
#   # dev.off()
#
#
#   predClass <- predict(mlModel, newdata = testX)
#
#   confusionMatrix(table(predict(mlModel, newdata = testX, type="prob")[,positiveClass] >= cutPoint,
#                         refactoredTestY == positiveClass))
# }
#
# #-----------------------------------------#
# # Machine learning
# #-----------------------------------------#
#
#
# # mlHvsC <- function(snmData){
# # Load dependencies
#
#
# mlHvsC <- function(snmData){
#
#   numCores <- detectCores()
#   registerDoMC(cores=numCores)
#
#   defaultGBMGrid <-  expand.grid(interaction.depth = seq(1,3),
#                                  n.trees = floor((1:3) * 50),
#                                  shrinkage = 0.1,
#                                  n.minobsinnode = 5)
#   customGBMGrid <-  expand.grid(interaction.depth = seq(1,3),
#                                 n.trees = floor((1:3) * 50),
#                                 shrinkage = 0.1,
#                                 n.minobsinnode = 1)
#
#   caretTuneGrid <- defaultGBMGrid
#   numKFold <- 4
#   numResampleIter <- 1
#
#   mlDataY <- metadataPSMatchedDPQCFiltered
#   mlDataX <- snmData[rownames(mlDataY),]
#
#   set.seed(42)
#   index <- createDataPartition(mlDataY$HvsC, p = 0.7, list = FALSE)
#   trainX <- mlDataX[index,]
#   trainY <- mlDataY[index,]$HvsC
#   testX <- mlDataX[-index,]
#   testY <- mlDataY[-index,]$HvsC
#   # print(testY)
#
#   refactoredTrainY <- factor(gsub('([[:punct:]])|\\s+','',trainY))
#   refactoredTestY <- factor(gsub('([[:punct:]])|\\s+','',testY))
#
#   set.seed(42)
#   ctrl <- trainControl(method = "repeatedcv",
#                        number = numKFold,
#                        repeats = numResampleIter,
#                        sampling = "up",
#                        summaryFunction = twoClassSummary,
#                        classProbs = TRUE,
#                        verboseIter = TRUE,
#                        savePredictions = TRUE,
#                        allowParallel=TRUE)
#
#   mlModel <- train(x = trainX,
#                    y = refactoredTrainY,
#                    method = "gbm",
#                    preProcess = c("scale","center"),
#                    trControl = ctrl,
#                    verbose = TRUE,
#                    metric = "ROC",
#                    tuneGrid = defaultGBMGrid)
#
#   positiveClass <- "Cancer"
#   negativeClass <- "Control"
#   predProbs <- as.numeric(predict(mlModel, newdata = testX, type = "prob")[,positiveClass])
#   fg <- predProbs[refactoredTestY == positiveClass]
#   bg <- predProbs[refactoredTestY == negativeClass]
#
#   prroc_roc <- roc.curve(scores.class0 = fg, scores.class1 = bg, curve = T)
#   prroc_pr <- pr.curve(scores.class0 = fg, scores.class1 = bg, curve = T, rand.compute=T)
#
#   plot(prroc_roc)
#   plot(prroc_pr)
#
#   predClass <- predict(mlModel, newdata = testX)
#   print(confusionMatrix(data = predClass, reference = refactoredTestY, positive = positiveClass))
# }
#
# #-----------------------------------------------------
#
# loocvDTs <- function(snmData, samplingSize = 15, DTs, caretTuneGrid = defaultGBMGrid,
#                      filenameString = paste(DTs,collapse = "__"), HvsCFlag = FALSE){
#
#   if(HvsCFlag){
#     metaTmpX <- droplevels(metadataPSMatchedDPQCFiltered[(metadataPSMatchedDPQCFiltered$disease_type_consol %in% DTs),])
#     metaTmpX$disease_type_consol <- metaTmpX$HvsC
#     classes <- gsub(" ","",levels(metaTmpX$disease_type_consol))
#   } else{
#     metaTmpX <- droplevels(metadataPSMatchedDPQCFiltered[(metadataPSMatchedDPQCFiltered$disease_type_consol %in% DTs),])
#     classes <- gsub(" ","",DTs)
#   }
#
#   # Do LOOCV model building and testing
#
#   multiClassSummaryStats <- list()
#   multiClassSummaryStatsDist <- list()
#   numKFold <- 4
#   numResampleIter <- 1
#   metaData <- metaTmpX
#   snmData <- snmData # dataPSUniqueDecontamQC #
#   iterSize <- 1
#   for(jj in 1:iterSize){
#     metadataSimSampled <- as.data.frame(stratified(metaData,
#                                                    group = "disease_type_consol",
#                                                    size = samplingSize,
#                                                    keep.rownames = TRUE,
#                                                    replace = FALSE,
#                                                    bothSets = FALSE))
#     rownames(metadataSimSampled) <- metadataSimSampled$rn
#     mlDataY <- metadataSimSampled
#     mlDataX <- snmData[rownames(mlDataY),]
#     dim(mlDataY)[1] == dim(mlDataX)[1] # Sanity check
#
#     # Create data partitions
#     # set.seed(42)
#     indexSuper <- 1:dim(mlDataY)[1]
#     predProbs <- list()
#     obsClass <- vector()
#     predClass <- vector()
#     varImpBestModelDF2OrderedNonzeroList <- list()
#
#     for(ii in 1:length(indexSuper)){
#       print(sprintf("Iteration: %d/%d", ii, length(indexSuper)))
#       index <- indexSuper[ii]
#       # print(index)
#       trainX <- mlDataX[-index,]
#       trainY <- mlDataY[-index,]$disease_type_consol
#       testX <- mlDataX[index,,drop=FALSE]
#       testY <- mlDataY[index,,drop=FALSE]$disease_type_consol
#       # print(testY)
#
#       refactoredTrainY <- factor(gsub('([[:punct:]])|\\s+','',trainY))
#       refactoredTestY <- factor(gsub('([[:punct:]])|\\s+','',testY))
#
#       obsClass[ii] <- as.character(refactoredTestY)
#
#       set.seed(42)
#       ctrl <- trainControl(method = "repeatedcv",
#                            number = numKFold,
#                            repeats = numResampleIter,
#                            sampling = "up",
#                            summaryFunction = multiClassSummary,
#                            classProbs = TRUE,
#                            verboseIter = FALSE,
#                            savePredictions = TRUE,
#                            allowParallel=TRUE)
#
#       mlModel <- train(x = trainX,
#                        y = refactoredTrainY,
#                        method = "gbm",
#                        preProcess = c("scale","center"),
#                        trControl = ctrl,
#                        verbose = FALSE,
#                        metric = "ROC",
#                        tuneGrid = caretTuneGrid)
#
#       predProbs[ii] <- list(predict(mlModel, newdata = testX, type = "prob"))
#       predClass[ii] <- as.character(predict(mlModel, newdata = testX, type = "raw"))
#
#       varImpBestModelDF <- as.data.frame(varImp( mlModel$finalModel, scale = FALSE ))
#       varImpBestModelDF2 <- rownames_to_column(varImpBestModelDF, "Taxa")
#       varImpBestModelDF2Ordered <- varImpBestModelDF2[order(-varImpBestModelDF2$Overall),]
#       colnames(varImpBestModelDF2Ordered)[2] <- "varImp"
#       varImpBestModelDF2OrderedNonzero <- varImpBestModelDF2Ordered[varImpBestModelDF2Ordered$varImp != 0,]
#       varImpBestModelDF2OrderedNonzeroList[[ii]] <- varImpBestModelDF2OrderedNonzero
#
#       rm(mlModel)
#     }
#
#     loocvPreds <- cbind(obs = factor(obsClass,
#                                      levels = classes),
#                         pred = factor(predClass,
#                                       levels = classes),
#                         do.call(rbind,predProbs))
#     # multiClassSummaryStats <- multiClassSummary(loocvPreds, lev = classes)
#     # print(multiClassSummaryStats)
#
#     multiClassSummaryStats[[jj]] <- multiClassSummary(loocvPreds, lev = classes)
#     print(multiClassSummaryStats[[jj]])
#
#     filenameROC <- paste0(filenameString,"__ROC.png")
#     filenamePR <- paste0(filenameString,"__PR.png")
#     filenameROCData <- paste0(filenameString,"__Data__ROC.csv")
#     filenamePRData <- paste0(filenameString,"__Data__PR.csv")
#     filenameSink <- paste0(filenameString,"__CM.txt")
#
#     predProbs <- loocvPreds[,DTs[1]]
#     fg <- predProbs[loocvPreds$obs == DTs[1]]
#     bg <- predProbs[loocvPreds$obs == DTs[2]]
#
#     prroc_roc <- roc.curve(scores.class0 = fg, scores.class1 = bg, curve = T)
#     prroc_pr <- pr.curve(scores.class0 = fg, scores.class1 = bg, curve = T, rand.compute=T)
#
#     png(filename=filenameROC, width = 6, height = 4, units = 'in', res = 300)
#     plot(prroc_roc)
#     dev.off()
#
#     png(filename=filenamePR, width = 6, height = 4, units = 'in', res = 300)
#     plot(prroc_pr)
#     dev.off()
#
#     rocCurveData <- cbind(as.data.frame(prroc_roc$curve), DT1 = DTs[1], DT2 = DTs[2])
#     prCurveData <- cbind(as.data.frame(prroc_pr$curve), DT1 = DTs[1], DT2 = DTs[2])
#
#     write.table(prCurveData, sep=",", file = filenamePRData, col.names = FALSE)
#     write.table(rocCurveData, sep=",", file = filenameROCData, col.names = FALSE)
#   }
#
#   print(confusionMatrix(loocvPreds$obs, loocvPreds$pred))
#   multiClassSummaryStatsDist <- data.frame(do.call(rbind, multiClassSummaryStats))
#
#   sink(filenameSink)
#   print(print(confusionMatrix(loocvPreds$obs, loocvPreds$pred)))
#   sink()
# }
#
# #-----------------------------------------------------
#
# ml2DTs <- function(snmData,
#                    classOfInterest = "Lung Adenocarcinoma",
#                    cutPoint = 0.5,
#                    samplingSize = 20,
#                    caretTuneGrid = defaultGBMGrid){
#
#   metaTmp1 <- droplevels(metadataPSMatchedDPQCFiltered[(metadataPSMatchedDPQCFiltered$disease_type_consol %in% c("PRAD",
#                                                                                                              "SKCM",
#                                                                                                              "NSCLC")),])
#   tmp <- metaTmp1
#   tmp$disease_type_consol <- factor(ifelse(metaTmp1$disease_type_consol == classOfInterest, yes = classOfInterest, no = "Other"))
#   metadataSimSampled <- as.data.frame(stratified(tmp,
#                                                  group = "disease_type_consol",
#                                                  size = samplingSize,
#                                                  keep.rownames = TRUE,
#                                                  replace = FALSE,
#                                                  bothSets = FALSE))
#   rownames(metadataSimSampled) <- metadataSimSampled$rn
#   mlDataY <- metadataSimSampled
#   mlDataX <- snmData[rownames(mlDataY),]
#
#   set.seed(42)
#   index <- createDataPartition(mlDataY$disease_type_consol, p = 0.7, list = FALSE)
#   trainX <- mlDataX[index,]
#   trainY <- mlDataY[index,]$disease_type_consol
#   testX <- mlDataX[-index,]
#   testY <- mlDataY[-index,]$disease_type_consol
#   # print(testY)
#
#   refactoredTrainY <- factor(gsub('([[:punct:]])|\\s+','',trainY))
#   refactoredTestY <- factor(gsub('([[:punct:]])|\\s+','',testY))
#
#   set.seed(42)
#   ctrl <- trainControl(method = "repeatedcv",
#                        number = numKFold,
#                        repeats = numResampleIter,
#                        sampling = "up",
#                        summaryFunction = twoClassSummary,
#                        classProbs = TRUE,
#                        verboseIter = TRUE,
#                        savePredictions = TRUE,
#                        allowParallel=TRUE)
#
#   mlModel <- train(x = trainX,
#                    y = refactoredTrainY,
#                    method = "gbm",
#                    preProcess = c("scale","center"),
#                    trControl = ctrl,
#                    verbose = TRUE,
#                    metric = "ROC",
#                    tuneGrid = customGBMGrid)
#
#   positiveClass <- gsub(" ","", classOfInterest)
#   negativeClass <- "Other"
#
#   predProbs <- as.numeric(predict(mlModel, newdata = testX, type = "prob")[,positiveClass])
#   fg <- predProbs[refactoredTestY == positiveClass]
#   bg <- predProbs[refactoredTestY == negativeClass]
#
#   prroc_roc <- roc.curve(scores.class0 = fg, scores.class1 = bg, curve = T)
#   prroc_pr <- pr.curve(scores.class0 = fg, scores.class1 = bg, curve = T, rand.compute=T)
#
#   # par(mfrow = c(1,2))
#   plot(prroc_roc)
#   plot(prroc_pr)
#   # dev.off()
#
#
#   predClass <- predict(mlModel, newdata = testX)
#
#   confusionMatrix(table(predict(mlModel, newdata = testX, type="prob")[,positiveClass] >= cutPoint,
#                         refactoredTestY == positiveClass))
# }

# %%
# %%R
# hVsC4 <- loocvDTs(snmData = snmDataKrakenCFDecontamDPQC,
#                  samplingSize = 100,
#                  DTs = c("Control","SKCM", "PRAD", "NSCLC"),
#                  caretTuneGrid = defaultGBMGrid, HvsCFlag = TRUE)
# Out:
# [1] "Iteration: 1/169"
# [1] "Iteration: 2/169"
# [1] "Iteration: 3/169"
# [1] "Iteration: 4/169"
# [1] "Iteration: 5/169"
# [1] "Iteration: 6/169"
# [1] "Iteration: 7/169"
# [1] "Iteration: 8/169"
# [1] "Iteration: 9/169"
# [1] "Iteration: 10/169"
# [1] "Iteration: 11/169"
# [1] "Iteration: 12/169"
# [1] "Iteration: 13/169"
# [1] "Iteration: 14/169"
# [1] "Iteration: 15/169"
# [1] "Iteration: 16/169"
# [1] "Iteration: 17/169"
# [1] "Iteration: 18/169"
# [1] "Iteration: 19/169"
# [1] "Iteration: 20/169"
# [1] "Iteration: 21/169"
# [1] "Iteration: 22/169"
# [1] "Iteration: 23/169"
# [1] "Iteration: 24/169"
# [1] "Iteration: 25/169"
# [1] "Iteration: 26/169"
# [1] "Iteration: 27/169"
# [1] "Iteration: 28/169"
# [1] "Iteration: 29/169"
# [1] "Iteration: 30/169"
# [1] "Iteration: 31/169"
# [1] "Iteration: 32/169"
# [1] "Iteration: 33/169"
# [1] "Iteration: 34/169"
# [1] "Iteration: 35/169"
# [1] "Iteration: 36/169"
# [1] "Iteration: 37/169"
# [1] "Iteration: 38/169"
# [1] "Iteration: 39/169"
# [1] "Iteration: 40/169"
# [1] "Iteration: 41/169"
# [1] "Iteration: 42/169"
# [1] "Iteration: 43/169"
# [1] "Iteration: 44/169"
# [1] "Iteration: 45/169"
# [1] "Iteration: 46/169"
# [1] "Iteration: 47/169"
# [1] "Iteration: 48/169"
# [1] "Iteration: 49/169"
# [1] "Iteration: 50/169"
# [1] "Iteration: 51/169"
# [1] "Iteration: 52/169"
# [1] "Iteration: 53/169"
# [1] "Iteration: 54/169"
# [1] "Iteration: 152/169"
# [1] "Iteration: 153/169"
# [1] "Iteration: 154/169"
# [1] "Iteration: 155/169"
# [1] "Iteration: 156/169"
# [1] "Iteration: 157/169"
# [1] "Iteration: 158/169"
# [1] "Iteration: 159/169"
# [1] "Iteration: 160/169"
# [1] "Iteration: 161/169"
# [1] "Iteration: 162/169"
# [1] "Iteration: 163/169"
# [1] "Iteration: 164/169"
# [1] "Iteration: 165/169"
# [1] "Iteration: 166/169"
# [1] "Iteration: 167/169"
# [1] "Iteration: 168/169"
# [1] "Iteration: 169/169"
#           logLoss               AUC             prAUC          Accuracy
#         0.3770009         0.9133333         0.8833191         0.8343195
#             Kappa                F1       Sensitivity       Specificity
#         0.6586351         0.8585859         0.8500000         0.8115942
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8673469         0.7887324         0.8673469         0.8500000
#    Detection_Rate Balanced_Accuracy
#         0.5029586         0.8307971
# Confusion Matrix and Statistics
#
#           Reference
# Prediction Cancer Control
#    Cancer      85      15
#    Control     13      56
#
#                Accuracy : 0.8343
#                  95% CI : (0.7695, 0.887)
#     No Information Rate : 0.5799
#     P-Value [Acc > NIR] : 1.226e-12
#
#                   Kappa : 0.6586
#  Mcnemar's Test P-Value : 0.8501
#
#             Sensitivity : 0.8673
#             Specificity : 0.7887
#          Pos Pred Value : 0.8500
#          Neg Pred Value : 0.8116
#              Prevalence : 0.5799
#          Detection Rate : 0.5030
#    Detection Prevalence : 0.5917
#       Balanced Accuracy : 0.8280
#
#        'Positive' Class : Cancer

# %%
# %%R
# hVsC_PRAD <- loocvDTs(snmData = snmDataKrakenCFDecontamDPQC,
#                  samplingSize = 69,
#                  DTs = c("PRAD","Control"),
#                  caretTuneGrid = defaultGBMGrid)
# Out:
# [1] "Iteration: 1/128"
# [1] "Iteration: 2/128"
# [1] "Iteration: 3/128"
# [1] "Iteration: 4/128"
# [1] "Iteration: 5/128"
# [1] "Iteration: 6/128"
# [1] "Iteration: 7/128"
# [1] "Iteration: 8/128"
# [1] "Iteration: 9/128"
# [1] "Iteration: 10/128"
# [1] "Iteration: 11/128"
# [1] "Iteration: 12/128"
# [1] "Iteration: 13/128"
# [1] "Iteration: 14/128"
# [1] "Iteration: 15/128"
# [1] "Iteration: 16/128"
# [1] "Iteration: 17/128"
# [1] "Iteration: 18/128"
# [1] "Iteration: 19/128"
# [1] "Iteration: 20/128"
# [1] "Iteration: 21/128"
# [1] "Iteration: 22/128"
# [1] "Iteration: 23/128"
# [1] "Iteration: 24/128"
# [1] "Iteration: 25/128"
# [1] "Iteration: 26/128"
# [1] "Iteration: 27/128"
# [1] "Iteration: 28/128"
# [1] "Iteration: 29/128"
# [1] "Iteration: 30/128"
# [1] "Iteration: 31/128"
# [1] "Iteration: 32/128"
# [1] "Iteration: 33/128"
# [1] "Iteration: 34/128"
# [1] "Iteration: 35/128"
# [1] "Iteration: 36/128"
# [1] "Iteration: 37/128"
# [1] "Iteration: 38/128"
# [1] "Iteration: 39/128"
# [1] "Iteration: 40/128"
# [1] "Iteration: 41/128"
# [1] "Iteration: 42/128"
# [1] "Iteration: 43/128"
# [1] "Iteration: 44/128"
# [1] "Iteration: 45/128"
# [1] "Iteration: 46/128"
# [1] "Iteration: 47/128"
# [1] "Iteration: 48/128"
# [1] "Iteration: 88/94"
# [1] "Iteration: 89/94"
# [1] "Iteration: 90/94"
# [1] "Iteration: 91/94"
# [1] "Iteration: 92/94"
# [1] "Iteration: 93/94"
# [1] "Iteration: 94/94"
#           logLoss               AUC             prAUC          Accuracy
#         0.2191174         0.9715942         0.9328949         0.9148936
#             Kappa                F1       Sensitivity       Specificity
#         0.7874505         0.8461538         0.8800000         0.9275362
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8148148         0.9552239         0.8148148         0.8800000
#    Detection_Rate Balanced_Accuracy
#         0.2340426         0.9037681
# Confusion Matrix and Statistics
#
#           Reference
# Prediction NSCLC Control
#    NSCLC      22       3
#    Control     5      64
#
#                Accuracy : 0.9149
#                  95% CI : (0.8392, 0.9625)
#     No Information Rate : 0.7128
#     P-Value [Acc > NIR] : 1.492e-06
#
#                   Kappa : 0.7875
#  Mcnemar's Test P-Value : 0.7237
#
#             Sensitivity : 0.8148
#             Specificity : 0.9552
#          Pos Pred Value : 0.8800
#          Neg Pred Value : 0.9275
#              Prevalence : 0.2872
#          Detection Rate : 0.2340
#    Detection Prevalence : 0.2660
#       Balanced Accuracy : 0.8850
#
#        'Positive' Class : NSCLC

# %%
# %%R
# hVsC_SKCM <- loocvDTs(snmData = snmDataKrakenCFDecontamDPQC,
#                  samplingSize = 69,
#                  DTs = c("SKCM","Control"),
#                  caretTuneGrid = defaultGBMGrid)
# Out:
# [1] "Iteration: 1/85"
# [1] "Iteration: 2/85"
# [1] "Iteration: 3/85"
# [1] "Iteration: 4/85"
# [1] "Iteration: 5/85"
# [1] "Iteration: 6/85"
# [1] "Iteration: 7/85"
# [1] "Iteration: 8/85"
# [1] "Iteration: 9/85"
# [1] "Iteration: 10/85"
# [1] "Iteration: 11/85"
# [1] "Iteration: 12/85"
# [1] "Iteration: 13/85"
# [1] "Iteration: 14/85"
# [1] "Iteration: 15/85"
# [1] "Iteration: 16/85"
# [1] "Iteration: 17/85"
# [1] "Iteration: 18/85"
# [1] "Iteration: 19/85"
# [1] "Iteration: 20/85"
# [1] "Iteration: 21/85"
# [1] "Iteration: 22/85"
# [1] "Iteration: 23/85"
# [1] "Iteration: 24/85"
# [1] "Iteration: 25/85"
# [1] "Iteration: 26/85"
# [1] "Iteration: 27/85"
# [1] "Iteration: 28/85"
# [1] "Iteration: 29/85"
# [1] "Iteration: 30/85"
# [1] "Iteration: 31/85"
# [1] "Iteration: 32/85"
# [1] "Iteration: 33/85"
# [1] "Iteration: 34/85"
# [1] "Iteration: 35/85"
# [1] "Iteration: 36/85"
# [1] "Iteration: 37/85"
# [1] "Iteration: 38/85"
# [1] "Iteration: 39/85"
# [1] "Iteration: 40/85"
# [1] "Iteration: 41/85"
# [1] "Iteration: 42/85"
# [1] "Iteration: 43/85"
# [1] "Iteration: 44/85"
# [1] "Iteration: 45/85"
# [1] "Iteration: 46/85"
# [1] "Iteration: 47/85"
# [1] "Iteration: 48/85"
# [1] "Iteration: 49/85"
# [1] "Iteration: 50/85"
# [1] "Iteration: 51/85"
# [1] "Iteration: 52/85"
# [1] "Iteration: 53/85"
# [1] "Iteration: 54/85"
# [1] "Iteration: 55/85"
# [1] "Iteration: 56/85"
# [1] "Iteration: 57/85"
# [1] "Iteration: 58/85"
# [1] "Iteration: 59/85"
# [1] "Iteration: 48/75"
# [1] "Iteration: 49/75"
# [1] "Iteration: 50/75"
# [1] "Iteration: 51/75"
# [1] "Iteration: 52/75"
# [1] "Iteration: 53/75"
# [1] "Iteration: 54/75"
# [1] "Iteration: 55/75"
# [1] "Iteration: 56/75"
# [1] "Iteration: 57/75"
# [1] "Iteration: 58/75"
# [1] "Iteration: 59/75"
# [1] "Iteration: 60/75"
# [1] "Iteration: 61/75"
# [1] "Iteration: 62/75"
# [1] "Iteration: 63/75"
# [1] "Iteration: 64/75"
# [1] "Iteration: 65/75"
# [1] "Iteration: 66/75"
# [1] "Iteration: 67/75"
# [1] "Iteration: 68/75"
# [1] "Iteration: 69/75"
# [1] "Iteration: 70/75"
# [1] "Iteration: 71/75"
# [1] "Iteration: 72/75"
# [1] "Iteration: 73/75"
# [1] "Iteration: 74/75"
# [1] "Iteration: 75/75"
#           logLoss               AUC             prAUC          Accuracy
#         0.3839484         0.8633475         0.7448466         0.8133333
#             Kappa                F1       Sensitivity       Specificity
#         0.4438559         0.8813559         0.8813559         0.5625000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8813559         0.5625000         0.8813559         0.8813559
#    Detection_Rate Balanced_Accuracy
#         0.6933333         0.7219280
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD SKCM
#       PRAD   52    7
#       SKCM    7    9
#
#                Accuracy : 0.8133
#                  95% CI : (0.7067, 0.894)
#     No Information Rate : 0.7867
#     P-Value [Acc > NIR] : 0.3446
#
#                   Kappa : 0.4439
#  Mcnemar's Test P-Value : 1.0000
#
#             Sensitivity : 0.8814
#             Specificity : 0.5625
#          Pos Pred Value : 0.8814
#          Neg Pred Value : 0.5625
#              Prevalence : 0.7867
#          Detection Rate : 0.6933
#    Detection Prevalence : 0.7867
#       Balanced Accuracy : 0.7219
#
#        'Positive' Class : PRAD

# %%
# %%R
# DT3 <- loocvDTs(snmData = snmDataKrakenCFDecontamDPQC,
#                  samplingSize = 59,
#                  DTs = c("PRAD","NSCLC","SKCM"),
#                  caretTuneGrid = defaultGBMGrid)
# Out:
# [1] "Iteration: 1/100"
# [1] "Iteration: 2/100"
# [1] "Iteration: 3/100"
# [1] "Iteration: 4/100"
# [1] "Iteration: 5/100"
# [1] "Iteration: 6/100"
# [1] "Iteration: 7/100"
# [1] "Iteration: 8/100"
# [1] "Iteration: 9/100"
# [1] "Iteration: 10/100"
# [1] "Iteration: 11/100"
# [1] "Iteration: 12/100"
# [1] "Iteration: 13/100"
# [1] "Iteration: 14/100"
# [1] "Iteration: 15/100"
# [1] "Iteration: 16/100"
# [1] "Iteration: 17/100"
# [1] "Iteration: 18/100"
# [1] "Iteration: 19/100"
# [1] "Iteration: 20/100"
# [1] "Iteration: 21/100"
# [1] "Iteration: 22/100"
# [1] "Iteration: 23/100"
# [1] "Iteration: 24/100"
# [1] "Iteration: 25/100"
# [1] "Iteration: 26/100"
# [1] "Iteration: 27/100"
# [1] "Iteration: 28/100"
# [1] "Iteration: 29/100"
# [1] "Iteration: 30/100"
# [1] "Iteration: 31/100"
# [1] "Iteration: 32/100"
# [1] "Iteration: 33/100"
# [1] "Iteration: 34/100"
# [1] "Iteration: 35/100"
# [1] "Iteration: 36/100"
# [1] "Iteration: 37/100"
# [1] "Iteration: 38/100"
# [1] "Iteration: 39/100"
# [1] "Iteration: 40/100"
# [1] "Iteration: 41/100"
# [1] "Iteration: 42/100"
# [1] "Iteration: 43/100"
# [1] "Iteration: 44/100"
# [1] "Iteration: 45/100"
# [1] "Iteration: 46/100"
# [1] "Iteration: 47/100"
# [1] "Iteration: 48/100"
# [1] "Iteration: 49/100"
# [1] "Iteration: 50/100"
# [1] "Iteration: 51/100"
# [1] "Iteration: 52/100"
# [1] "Iteration: 53/100"
# [1] "Iteration: 54/100"
# [1] "Iteration: 55/100"
# [1] "Iteration: 56/100"
# [1] "Iteration: 57/100"
# [1] "Iteration: 58/100"
# [1] "Iteration: 59/100"
# [1] "Iteration: 60/100"
# [1] "Iteration: 61/100"
# [1] "Iteration: 62/100"
# [1] "Iteration: 63/100"
# [1] "Iteration: 64/100"
# [1] "Iteration: 65/100"
# [1] "Iteration: 66/100"
# [1] "Iteration: 67/100"
# [1] "Iteration: 68/100"
# [1] "Iteration: 69/100"
# [1] "Iteration: 70/100"
# [1] "Iteration: 71/100"
# [1] "Iteration: 72/100"
# [1] "Iteration: 73/100"
# [1] "Iteration: 74/100"
# [1] "Iteration: 75/100"
# [1] "Iteration: 76/100"
# [1] "Iteration: 77/100"
# [1] "Iteration: 78/100"
# [1] "Iteration: 79/100"
# [1] "Iteration: 80/100"
# [1] "Iteration: 81/100"
# [1] "Iteration: 82/100"
# [1] "Iteration: 83/100"
# [1] "Iteration: 84/100"
# [1] "Iteration: 85/100"
# [1] "Iteration: 86/100"
# [1] "Iteration: 87/100"
# [1] "Iteration: 88/100"
# [1] "Iteration: 89/100"
# [1] "Iteration: 90/100"
# [1] "Iteration: 91/100"
# [1] "Iteration: 92/100"
# [1] "Iteration: 93/100"
# [1] "Iteration: 94/100"
# [1] "Iteration: 95/100"
# [1] "Iteration: 96/100"
# [1] "Iteration: 97/100"
# [1] "Iteration: 98/100"
# [1] "Iteration: 99/100"
# [1] "Iteration: 100/100"
#                logLoss                    AUC                  prAUC
#              0.5891643              0.8689838              0.7203866
#               Accuracy                  Kappa                Mean_F1
#              0.7400000              0.5199409              0.6616332
#       Mean_Sensitivity       Mean_Specificity    Mean_Pos_Pred_Value
#              0.6473023              0.8361789              0.6821734
#    Mean_Neg_Pred_Value         Mean_Precision            Mean_Recall
#              0.8509511              0.6821734              0.6473023
#    Mean_Detection_Rate Mean_Balanced_Accuracy
#              0.2466667              0.7417406
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD NSCLC SKCM
#      PRAD    51     3    5
#      NSCLC    7    16    2
#      SKCM     7     2    7
#
# Overall Statistics
#
#                Accuracy : 0.74
#                  95% CI : (0.6427, 0.8226)
#     No Information Rate : 0.65
#     P-Value [Acc > NIR] : 0.03514
#
#                   Kappa : 0.5199
#  Mcnemar's Test P-Value : 0.58636
#
# Statistics by Class:
#
#                      Class: PRAD Class: NSCLC Class: SKCM
# Sensitivity               0.7846       0.7619      0.5000
# Specificity               0.7714       0.8861      0.8953
# Pos Pred Value            0.8644       0.6400      0.4375
# Neg Pred Value            0.6585       0.9333      0.9167
# Prevalence                0.6500       0.2100      0.1400
# Detection Rate            0.5100       0.1600      0.0700
# Detection Prevalence      0.5900       0.2500      0.1600
# Balanced Accuracy         0.7780       0.8240      0.6977

# %%
# %%R
# DTH4 <- loocvDTs(snmData = snmDataKrakenCFDecontamDPQC,
#                  samplingSize = 69,
#                  DTs = c
#    Mean_Neg_Pred_Value         Mean_Precision            Mean_Recall
#              0.8707809              0.7167925              0.7062081
#    Mean_Detection_Rate Mean_Balanced_Accuracy
#              0.2505447              0.7876450
# Confusion Matrix and Statistics
#
#           Reference
# Prediction Control PRAD NSCLC
#    Control      53   10     6
#    PRAD          7   49     3
#    NSCLC         4    8    13
#
# Overall Statistics
#
#                Accuracy : 0.7516
#                  95% CI : (0.6754, 0.8179)
#     No Information Rate : 0.4379
#     P-Value [Acc > NIR] : 3.132e-15
#
#                   Kappa : 0.5988
#  Mcnemar's Test P-Value : 0.3615
#
# Statistics by Class:
#
#                      Class: Control Class: PRAD Class: NSCLC
# Sensitivity                  0.8281      0.7313      0.59091
# Specificity                  0.8202      0.8837      0.90840
# Pos Pred Value               0.7681      0.8305      0.52000
# Neg Pred Value               0.8690      0.8085      0.92969
# Prevalence                   0.4183      0.4379      0.14379
# Detection Rate               0.3464      0.3203      0.08497
# Detection Prevalence         0.4510      0.3856      0.16340
# Balanced Accuracy            0.8242      0.8075      0.74965

# %% [markdown]
# # Examining subsampling effects on PC and LC
# In order to see if the reduced performance of the melanoma group is due to too few samples

# %%
# %%R
# # Load dependencies
# require(devtools)
# require(doMC)
# require(tibble)
# require(gbm)
# require(splitstackshape)
# require(reshape2)
# require(ggpubr)
# require(caret) # for model building
# require(pROC) # for AUC calculations
# require(purrr) # for functional programming using map()
# require(dplyr) # for data manipulation
# require(doMC) # for parallel computing
# require(gbm) # for machine learning
# require(tibble) # for df operations
# require(cowplot) # for plotting
# require(PRROC) # for precision-recall curves
# require(MLmetrics) # for multi-class learning
# require(caret) # for machine learning
#
# numCores <- detectCores()
# registerDoMC(cores=numCores)
#
# defaultGBMGrid <-  expand.grid(interaction.depth = seq(1,3),
#                                n.trees = floor((1:3) * 50),
#                                shrinkage = 0.1,
#                                n.minobsinnode = 5)
# customGBMGrid <-  expand.grid(interaction.depth = seq(1,3),
#                               n.trees = floor((1:3) * 50),
#                               shrinkage = 0.1,
#                               n.minobsinnode = 1)
# numKFold <- 4
# numResampleIter <- 1
# # iterSize <- 100
#
# #-------------------------------------#
# ## Main function
# #-------------------------------------#
#
# loocvDTs_subsample <- function(snmData, samplingSize = 16, DTs, iterSize = 100, caretTuneGrid = defaultGBMGrid,
#                                filenameString = paste(DTs,collapse = "__"), HvsCFlag = FALSE){
#
#   if(HvsCFlag){
#     metaTmpX <- droplevels(metadataPSMatchedDPQCFiltered[(metadataPSMatchedDPQCFiltered$disease_type_consol %in% DTs),])
#     metaTmpX$disease_type_consol <- metaTmpX$HvsC
#     classes <- gsub(" ","",levels(metaTmpX$disease_type_consol))
#   } else{
#     metaTmpX <- droplevels(metadataPSMatchedDPQCFiltered[(metadataPSMatchedDPQCFiltered$disease_type_consol %in% DTs),])
#     classes <- gsub(" ","",DTs)
#   }
#
#   rownameSubsampleList <- t(lapply(1:iterSize, function(x) as.data.frame(stratified(metaTmpX,
#                                                                    group = "disease_type_consol",
#                                                                    size = samplingSize,
#                                                                    keep.rownames = TRUE,
#                                                                    replace = FALSE,
#                                                                    bothSets = FALSE))$rn))
#
#   # Do LOOCV model building and testing
#
#   multiClassSummaryStats <- list()
#   multiClassSummaryStatsDist <- list()
#   numKFold <- 4
#   numResampleIter <- 1
#   metaData <- metaTmpX
#   snmData <- snmData # dataPSUniqueDecontamQC #
#   iterSize <- iterSize
#   for(jj in 1:iterSize){
#     print(sprintf("Sub-Sampling Iteration: %d/%d", jj, iterSize))
#
#     mlDataY <- droplevels(metaData[rownameSubsampleList[[jj]],])
#     mlDataX <- snmData[rownames(mlDataY),]
#     dim(mlDataY)[1] == dim(mlDataX)[1] # Sanity check
#
#     print(rownames(mlDataY))
#
#     indexSuper <- 1:dim(mlDataY)[1]
#     predProbs <- list()
#     obsClass <- vector()
#     predClass <- vector()
#     varImpBestModelDF2OrderedNonzeroList <- list()
#
#     for(ii in 1:length(indexSuper)){
#       print(sprintf("LOOCV Iteration: %d/%d", ii, length(indexSuper)))
#       index <- indexSuper[ii]
#       # print(index)
#       trainX <- mlDataX[-index,]
#       trainY <- mlDataY[-index,]$disease_type_consol
#       testX <- mlDataX[index,,drop=FALSE]
#       testY <- mlDataY[index,,drop=FALSE]$disease_type_consol
#       # print(testY)
#
#       refactoredTrainY <- factor(gsub('([[:punct:]])|\\s+','',trainY))
#       refactoredTestY <- factor(gsub('([[:punct:]])|\\s+','',testY))
#
#       obsClass[ii] <- as.character(refactoredTestY)
#
#       set.seed(42)
#       ctrl <- trainControl(method = "repeatedcv",
#                            number = numKFold,
#                            repeats = numResampleIter,
#                            sampling = "up",
#                            summaryFunction = multiClassSummary,
#                            classProbs = TRUE,
#                            verboseIter = FALSE,
#                            savePredictions = TRUE,
#                            allowParallel=TRUE)
#
#       mlModel <- train(x = trainX,
#                        y = refactoredTrainY,
#                        method = "gbm",
#                        preProcess = c("scale","center"),
#                        trControl = ctrl,
#                        verbose = FALSE,
#                        metric = "ROC",
#                        tuneGrid = caretTuneGrid)
#
#       predProbs[ii] <- list(predict(mlModel, newdata = testX, type = "prob"))
#       predClass[ii] <- as.character(predict(mlModel, newdata = testX, type = "raw"))
#
#
#       rm(mlModel)
#     }
#
#     loocvPreds <- cbind(obs = factor(obsClass,
#                                      levels = classes),
#                         pred = factor(predClass,
#                                       levels = classes),
#                         do.call(rbind,predProbs))
#
#     multiClassSummaryStats[[jj]] <- multiClassSummary(loocvPreds, lev = classes)
#
#     print(confusionMatrix(loocvPreds$obs, loocvPreds$pred))
#     print(multiClassSummaryStats[[jj]])
#
#   }
#
#   multiClassSummaryStatsDist <- data.frame(do.call(rbind, multiClassSummaryStats))
#   print(multiClassSummaryStatsDist)
#   filenamePerfDist <- paste0(filenameString,"__iter",iterSize,"__PerfDist.csv")
#   write.csv(multiClassSummaryStatsDist, file = filenamePerfDist)
#
#   aucrocCI <- ci(multiClassSummaryStatsDist$AUC)
#   auprCI <- ci(multiClassSummaryStatsDist$prAUC)
#
#   print(paste0("Mean AUCROC = ",round(aucrocCI[1],4)," | 95% CI: [",
#                round(aucrocCI[2],4),",",round(aucrocCI[3],4),"]"))
#
#   print(paste0("Mean AUPR = ",round(auprCI[1],4)," | 95% CI: [",
#                round(auprCI[2],4),",",round(auprCI[3],4),"]"))
#
#   return(multiClassSummaryStatsDist)
#
# }

# %%
# %%R
# prad_control_ss16 <- loocvDTs_subsample(snmData = snmDataKrakenCFDecontamDPQC,
#                                       samplingSize = 16,
#                                       iterSize = 100,
#                                       DTs = c("PRAD","Control"),
#                                       caretTuneGrid = defaultGBMGrid)
# save(prad_control_ss16, file = "prad_control_ss16_100.RData")
# Out:
# [1] "Sub-Sampling Iteration: 1/100"
#  [1] "12667.X2457964" "12667.X2036793" "12667.X3106774" "12667.X2050079"
#  [5] "12667.X2043129" "12667.X2036767" "12667.X2339235" "12667.X2043400"
#  [9] "12667.X2062455" "12667.X2047268" "12667.X2403412" "12667.X3004746"
# [13] "12667.X2056691" "12667.X2048152" "12667.X2069281" "12667.X2071711"
# [17] "12691.rana23"   "12691.rana19"   "12691.rana14"   "12691.rana30"
# [21] "12691.rana45"   "12691.rana20"   "12691.rana56"   "12691.rana41"
# [25] "12691.rana53"   "12691.rana44"   "12691.rana11"   "12691.rana55"
# [29] "12691.rana01"   "12691.rana24"   "12691.rana26"   "12691.rana02"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      15       1
#    Control    3      13
#
#                Accuracy : 0.875
#                  95% CI : (0.7101, 0.9649)
#     No Information Rate : 0.5625
#     P-Value [Acc > NIR] : 0.0001596
#
#                   Kappa : 0.75
#  Mcnemar's Test P-Value : 0.6170751
#
#             Sensitivity : 0.8333
#             Specificity : 0.9286
#          Pos Pred Value : 0.9375
#          Neg Pred Value : 0.8125
#              Prevalence : 0.5625
#          Detection Rate : 0.4688
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.8810
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.3518831         0.9414062         0.8834786         0.8750000
#             Kappa                F1       Sensitivity       Specificity
#         0.7500000         0.8823529         0.9375000         0.8125000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8333333         0.9285714         0.8333333         0.9375000
#    Detection_Rate Balanced_Accuracy
#         0.4687500         0.8750000
# [1] "Sub-Sampling Iteration: 2/100"
#  [1] "12667.X3034050" "12667.X2047268" "12667.X3106774" "12667.X2052835"
#  [5] "12667.X2472337" "12667.X2493385" "12667.X3003105" "12667.X3004746"
#  [9] "12667.X2049520" "12667.X2064352" "12667.X2036793" "12667.X2051138"
# [13] "12667.X2059586" "12667.X3122336" "12667.X2058733" "12667.X2050079"
# [17] "12691.rana26"   "12691.rana34"   "12691.rana21"   "12691.rana35"
# [21] "12691.rana24"   "12691.rana44"   "12691.rana32"   "12691.rana30"
# [25] "12691.rana14"   "12691.rana25"   "12691.rana07"   "12691.rana45"
# [29] "12691.rana18"   "12691.rana55"   "12691.rana17"   "12691.rana22"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      15       1
#    Control    2      14
#
#                Accuracy : 0.9062
#                  95% CI : (0.7498, 0.9802)
#     No Information Rate : 0.5312
#     P-Value [Acc > NIR] : 6.193e-06
#
#                   Kappa : 0.8125
#  Mcnemar's Test P-Value : 1
#
#             Sensitivity : 0.8824
#             Specificity : 0.9333
#          Pos Pred Value : 0.9375
#          Neg Pred Value : 0.8750
#              Prevalence : 0.5312
#          Detection Rate : 0.4688
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.9078
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.4036847         0.8984375         0.8235719         0.9062500
#             Kappa                F1       Sensitivity       Specificity
#         0.8125000         0.9090909         0.9375000         0.8750000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8823529         0.9333333         0.8823529         0.9375000
#    Detection_Rate Balanced_Accuracy
#         0.4687500         0.9062500
# [1] "Sub-Sampling Iteration: 3/100"
#  [1] "12667.X2488000" "12667.X2056691" "12667.X2062809" "12667.X2471017"
#  [5] "12667.X2483184" "12667.X3106774" "12667.X2048152" "12667.X2049520"
#  [9] "12667.X2076954" "12667.X2051123" "12667.X3054832" "12667.X3109641"
# [13] "12667.X2061574" "12667.X2067131" "12667.X2052835" "12667.X2052632"
# [17] "12691.rana09"   "12691.rana11"   "12691.rana61"   "12691.rana10"
# [21] "12691.rana17"   "12691.rana32"   "12691.rana15"   "12691.rana60"
# [25] "12691.rana56"   "12691.rana51"   "12691.rana18"   "12691.rana08"
# [29] "12691.rana42"   "12691.rana03"   "12691.rana26"   "12691.rana53"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      14       2
#    Control    3      13
#
#                Accuracy : 0.8438
#                  95% CI : (0.6721, 0.9472)
#     No Information Rate : 0.5312
#     P-Value [Acc > NIR] : 0.000216
#
#                   Kappa : 0.6875
#  Mcnemar's Test P-Value : 1.000000
#
#             Sensitivity : 0.8235
#             Specificity : 0.8667
#          Pos Pred Value : 0.8750
#          Neg Pred Value : 0.8125
#              Prevalence : 0.5312
#          Detection Rate : 0.4375
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.8451
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.3904724         0.9609375         0.9011843         0.8437500
#             Kappa                F1       Sensitivity       Specificity
#         0.6875000         0.8484848         0.8750000         0.8125000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8235294         0.8666667         0.8235294         0.8750000
#    Detection_Rate Balanced_Accuracy
#         0.4375000         0.8437500
# [1] "Sub-Sampling Iteration: 4/100"
#  [1] "12667.X2049520" "12667.X2055755" "12667.X2076870" "12667.X2059586"
#  [5] "12667.X2064367" "12667.X2457964" "12667.X2074003" "12667.X3074166"
#  [9] "12667.X2051138" "12667.X2069281" "12667.X2496221" "12667.X2043129"
# [13] "12667.X3056486" "12667.X2061359" "12667.X2062971" "12667.X2483184"
# [17] "12691.rana18"   "12691.rana28"   "12691.rana39"   "12691.rana20"
# [21] "12691.rana06"   "12691.rana22"   "12691.rana45"   "12691.rana19"
# [25] "12691.rana30"   "12691.rana23"   "12691.rana41"   "12691.rana35"
# [29] "12691.rana53"   "12691.rana09"   "12691.rana50"   "12691.rana17"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      16       0
#    Control    1      15
#
#                Accuracy : 0.9688
#                  95% CI : (0.8378, 0.9992)
#     No Information Rate : 0.5312
#     P-Value [Acc > NIR] : 4.737e-08
#
#                   Kappa : 0.9375
#  Mcnemar's Test P-Value : 1
#
#             Sensitivity : 0.9412
#             Specificity : 1.0000
#          Pos Pred Value : 1.0000
#          Neg Pred Value : 0.9375
#              Prevalence : 0.5312
#          Detection Rate : 0.5000
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.9706
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.1767149         0.9609375         0.8974681         0.9687500
#             Kappa                F1       Sensitivity       Specificity
#         0.9375000         0.9696970         1.0000000         0.9375000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.9411765         1.0000000         0.9411765         1.0000000
#    Detection_Rate Balanced_Accuracy
#         0.5000000         0.9687500
# [1] "Sub-Sampling Iteration: 5/100"
#  [1] "12667.X2061359" "12667.X2170593" "12667.X2454843" "12667.X2488349"
#  [5] "12667.X2059586" "12667.X2055755" "12667.X3054832" "12667.X3030973"
#  [9] "12667.X2130028" "12667.X2471017" "12667.X2068980" "12667.X2076954"
# [13] "12667.X2036793" "12667.X2049520" "12667.X2061574" "12667.X2496221"
# [17] "12691.rana44"   "12691.rana03"   "12691.rana33"   "12691.rana32"
# [21] "12691.rana28"   "12691.rana21"   "12691.rana40"   "12691.rana05"
# [25] "12691.rana23"   "12691.rana34"   "12691.rana37"   "12691.rana61"
# [29] "12691.rana51"   "12691.rana30"   "12691.rana25"   "12691.rana15"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      14       2
#    Control    1      15
#
#                Accuracy : 0.9062
#                  95% CI : (0.7498, 0.9802)
#     No Information Rate : 0.5312
#     P-Value [Acc > NIR] : 6.193e-06
#
#                   Kappa : 0.8125
#  Mcnemar's Test P-Value : 1
#
#             Sensitivity : 0.9333
#             Specificity : 0.8824
#          Pos Pred Value : 0.8750
#          Neg Pred Value : 0.9375
#              Prevalence : 0.4688
#          Detection Rate : 0.4375
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.9078
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.3271381         0.9218750         0.8472844         0.9062500
#             Kappa                F1       Sensitivity       Specificity
#         0.8125000         0.9032258         0.8750000         0.9375000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.9333333         0.8823529         0.9333333         0.8750000
#    Detection_Rate Balanced_Accuracy
#         0.4375000         0.9062500
# [1] "Sub-Sampling Iteration: 6/100"
#  [1] "12667.X2062971" "12667.X2472337" "12667.X2064352" "12667.X3056486"
#  [5] "12667.X2049520" "12667.X2483184" "12667.X2493385" "12667.X2048152"
#  [9] "12667.X3030973" "12667.X3106774" "12667.X3109641" "12667.X3054832"
# [13] "12667.X3003105" "12667.X2339235" "12667.X2457964" "12667.X3034050"
# [17] "12691.rana41"   "12691.rana43"   "12691.rana49"   "12691.rana15"
# [21] "12691.rana13"   "12691.rana21"   "12691.rana33"   "12691.rana50"
# [25] "12691.rana51"   "12691.rana01"   "12691.rana38"   "12691.rana04"
# [29] "12691.rana07"   "12691.rana24"   "12691.rana22"   "12691.rana17"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      15       1
#    Control    3      13
#
#                Accuracy : 0.875
#                  95% CI : (0.7101, 0.9649)
#     No Information Rate : 0.5625
#     P-Value [Acc > NIR] : 0.0001596
#
#                   Kappa : 0.75
#  Mcnemar's Test P-Value : 0.6170751
#
#             Sensitivity : 0.8333
#             Specificity : 0.9286
#          Pos Pred Value : 0.9375
#          Neg Pred Value : 0.8125
#              Prevalence : 0.5625
#          Detection Rate : 0.4688
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.8810
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.4818006         0.8789062         0.7894090         0.8750000
#             Kappa                F1       Sensitivity       Specificity
#         0.7500000         0.8823529         0.9375000         0.8125000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8333333         0.9285714         0.8333333         0.9375000
#    Detection_Rate Balanced_Accuracy
#         0.4687500         0.8750000
# [1] "Sub-Sampling Iteration: 7/100"
#  [1] "12667.X2036767" "12667.X3074166" "12667.X2061316" "12667.X2076870"
#  [5] "12667.X2454843" "12667.X2059586" "12667.X2036793" "12667.X3054832"
#  [9] "12667.X2068980" "12667.X3030973" "12667.X3106774" "12667.X2147547"
# [13] "12667.X2052835" "12667.X3076646" "12667.X2342267" "12667.X2056691"
# [17] "12691.rana54"   "12691.rana29"   "12691.rana28"   "12691.rana50"
# [21] "12691.rana40"   "12691.rana41"   "12691.rana11"   "12691.rana20"
# [25] "12691.rana03"   "12691.rana42"   "12691.rana15"   "12691.rana22"
# [29] "12691.rana56"   "12691.rana36"   "12691.rana38"   "12691.rana37"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      14       2
#    Control    2      14
#
#                Accuracy : 0.875
#                  95% CI : (0.7101, 0.9649)
#     No Information Rate : 0.5
#     P-Value [Acc > NIR] : 9.651e-06
#
#                   Kappa : 0.75
#  Mcnemar's Test P-Value : 1
#
#             Sensitivity : 0.8750
#             Specificity : 0.8750
#          Pos Pred Value : 0.8750
#          Neg Pred Value : 0.8750
#              Prevalence : 0.5000
#          Detection Rate : 0.4375
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.8750
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.4221224         0.8710938         0.7974191         0.8750000
#             Kappa                F1       Sensitivity       Specificity
#         0.7500000         0.8750000         0.8750000         0.8750000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8750000         0.8750000         0.8750000         0.8750000
#    Detection_Rate Balanced_Accuracy
#         0.4375000         0.8750000
# [1] "Sub-Sampling Iteration: 8/100"
#  [1] "12667.X2378267" "12667.X2043129" "12667.X2061359" "12667.X2065210"
#  [5] "12667.X2062455" "12667.X2454843" "12667.X2061316" "12667.X2472337"
#  [9] "12667.X2483184" "12667.X2069281" "12667.X3030973" "12667.X2342267"
# [13] "12667.X2051138" "12667.X2056691" "12667.X3106774" "12667.X3003105"
# [17] "12691.rana03"   "12691.rana56"   "12691.rana23"   "12691.rana11"
# [21] "12691.rana60"   "12691.rana39"   "12691.rana36"   "12691.rana08"
# [25] "12691.rana51"   "12691.rana38"   "12691.rana15"   "12691.rana12"
# [29] "12691.rana40"   "12691.rana05"   "12691.rana24"   "12691.rana22"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      14       2
#    Control    1      15
#
#                Accuracy : 0.9062
#                  95% CI : (0.7498, 0.9802)
#     No Information Rate : 0.5312
#     P-Value [Acc > NIR] : 6.193e-06
#
#                   Kappa : 0.8125
#  Mcnemar's Test P-Value : 1
#
#             Sensitivity : 0.9333
#             Specificity : 0.8824
#          Pos Pred Value : 0.8750
#          Neg Pred Value : 0.9375
#              Prevalence : 0.4688
#          Detection Rate : 0.4375
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.9078
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.3988386         0.8906250         0.8191428         0.9062500
#             Kappa                F1       Sensitivity       Specificity
#         0.8125000         0.9032258         0.8750000         0.9375000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.9333333         0.8823529         0.9333333         0.8750000
#    Detection_Rate Balanced_Accuracy
#         0.4375000         0.9062500
# [1] "Sub-Sampling Iteration: 9/100"
#  [1] "12667.X2076954" "12667.X2052835" "12667.X2068980" "12667.X2471017"
#  [5] "12667.X2488349" "12667.X2457964" "12667.X2147547" "12667.X2067131"
#  [9] "12667.X2071711" "12667.X2036793" "12667.X2454843" "12667.X2069281"
# [13] "12667.X2470952" "12667.X3124859" "12667.X2043129" "12667.X2048152"
# [17] "12691.rana60"   "12691.rana37"   "12691.rana22"   "12691.rana26"
# [21] "12691.rana39"   "12691.rana49"   "12691.rana33"   "12691.rana48"
# [25] "12691.rana15"   "12691.rana25"   "12691.rana09"   "12691.rana24"
# [29] "12691.rana02"   "12691.rana50"   "12691.rana61"   "12691.rana43"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      14       2
#    Control    4      12
#
#                Accuracy : 0.8125
#                  95% CI : (0.6356, 0.9279)
#     No Information Rate : 0.5625
#     P-Value [Acc > NIR] : 0.002762
#
#                   Kappa : 0.625
#  Mcnemar's Test P-Value : 0.683091
#
#             Sensitivity : 0.7778
#             Specificity : 0.8571
#          Pos Pred Value : 0.8750
#          Neg Pred Value : 0.7500
#              Prevalence : 0.5625
#          Detection Rate : 0.4375
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.8175
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.5161295         0.8750000         0.8028625         0.8125000
#             Kappa                F1       Sensitivity       Specificity
#         0.6250000         0.8235294         0.8750000         0.7500000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.7777778         0.8571429         0.7777778         0.8750000
#    Detection_Rate Balanced_Accuracy
#         0.4375000         0.8125000
# [1] "Sub-Sampling Iteration: 10/100"
#  [1] "12667.X2036793" "12667.X2061574" "12667.X3030973" "12667.X3004746"
#  [5] "12667.X2378267" "12667.X2041787" "12667.X2069281" "12667.X2065210"
#  [9] "12667.X2067131" "12667.X2454843" "12667.X3124859" "12667.X2493385"
# [13] "12667.X2058733" "12667.X2488000" "12667.X2050079" "12667.X3109641"
# [17] "12691.rana03"   "12691.rana48"   "12691.rana17"   "12691.rana12"
# [21] "12691.rana11"   "12691.rana09"   "12691.rana47"   "12691.rana45"
# [25] "12691.rana42"   "12691.rana27"   "12691.rana59"   "12691.rana49"
# [29] "12691.rana25"   "12691.rana60"   "12691.rana52"   "12691.rana36"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      14       2
#    Control    4      12
#
#                Accuracy : 0.8125
#                  95% CI : (0.6356, 0.9279)
#     No Information Rate : 0.5625
#     P-Value [Acc > NIR] : 0.002762
#
#                   Kappa : 0.625
#  Mcnemar's Test P-Value : 0.683091
#
#             Sensitivity : 0.7778
#             Specificity : 0.8571
#          Pos Pred Value : 0.8750
#          Neg Pred Value : 0.7500
#              Prevalence : 0.5625
#          Detection Rate : 0.4375
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.8175
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.4602592         0.9101562         0.8547017         0.8125000
#             Kappa                F1       Sensitivity       Specificity
#         0.6250000         0.8235294         0.8750000         0.7500000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.7777778         0.8571429         0.7777778         0.8750000
#    Detection_Rate Balanced_Accuracy
#         0.4375000         0.8125000
# [1] "Sub-Sampling Iteration: 11/100"
#  [1] "12667.X2067131" "12667.X3034050" "12667.X2493385" "12667.X2062809"
#  [5] "12667.X2339235" "12667.X2041787" "12667.X2062455" "12667.X2483184"
#  [9] "12667.X2065210" "12667.X2060998" "12667.X2051123" "12667.X3122336"
# [13] "12667.X2036793" "12667.X2378267" "12667.X2068559" "12667.X2047268"
# [17] "12691.rana50"   "12691.rana35"   "12691.rana17"   "12691.rana01"
# [21] "12691.rana27"   "12691.rana32"   "12691.rana42"   "12691.rana04"
# [25] "12691.rana31"   "12691.rana02"   "12691.rana26"   "12691.rana30"
# [29] "12691.rana46"   "12691.rana37"   "12691.rana55"   "12691.rana11"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      16       0
#    Control    3      13
#
#                Accuracy : 0.9062
#                  95% CI : (0.7498, 0.9802)
#     No Information Rate : 0.5938
#     P-Value [Acc > NIR] : 0.000105
#
#                   Kappa : 0.8125
#  Mcnemar's Test P-Value : 0.248213
#
#             Sensitivity : 0.8421
#             Specificity : 1.0000
#          Pos Pred Value : 1.0000
#          Neg Pred Value : 0.8125
#              Prevalence : 0.5938
#          Detection Rate : 0.5000
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.9211
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.3461070         0.8984375         0.8152315         0.9062500
#             Kappa                F1       Sensitivity       Specificity
#         0.8125000         0.9142857         1.0000000         0.8125000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8421053         1.0000000         0.8421053         1.0000000
#    Detection_Rate Balanced_Accuracy
#         0.5000000         0.9062500
# [1] "Sub-Sampling Iteration: 12/100"
#  [1] "12667.X2071711" "12667.X2041787" "12667.X2403412" "12667.X2068980"
#  [5] "12667.X2060998" "12667.X3030973" "12667.X3034050" "12667.X3039009"
#  [9] "12667.X2062809" "12667.X2065210" "12667.X2454843" "12667.X2069281"
# [13] "12667.X3074166" "12667.X3122336" "12667.X2055755" "12667.X2050079"
# [17] "12691.rana29"   "12691.rana17"   "12691.rana16"   "12691.rana02"
# [21] "12691.rana24"   "12691.rana52"   "12691.rana49"   "12691.rana12"
# [25] "12691.rana22"   "12691.rana10"   "12691.rana13"   "12691.rana05"
# [29] "12691.rana21"   "12691.rana26"   "12691.rana34"   "12691.rana59"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      13       3
#    Control    3      13
#
#                Accuracy : 0.8125
#                  95% CI : (0.6356, 0.9279)
#     No Information Rate : 0.5
#     P-Value [Acc > NIR] : 0.0002675
#
#                   Kappa : 0.625
#  Mcnemar's Test P-Value : 1.0000000
#
#             Sensitivity : 0.8125
#             Specificity : 0.8125
#          Pos Pred Value : 0.8125
#          Neg Pred Value : 0.8125
#              Prevalence : 0.5000
#          Detection Rate : 0.4062
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.8125
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.5043522         0.8984375         0.8368553         0.8125000
#             Kappa                F1       Sensitivity       Specificity
#         0.6250000         0.8125000         0.8125000         0.8125000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8125000         0.8125000         0.8125000         0.8125000
#    Detection_Rate Balanced_Accuracy
#         0.4062500         0.8125000
# [1] "Sub-Sampling Iteration: 13/100"
#  [1] "12667.X2470952" "12667.X2339235" "12667.X3030973" "12667.X3074166"
#  [5] "12667.X2062455" "12667.X2064367" "12667.X3076646" "12667.X2068559"
#  [9] "12667.X2457964" "12667.X2036767" "12667.X2052632" "12667.X2044156"
# [13] "12667.X3106774" "12667.X2076870" "12667.X2064352" "12667.X2058733"
# [17] "12691.rana08"   "12691.rana19"   "12691.rana10"   "12691.rana27"
# [21] "12691.rana05"   "12691.rana22"   "12691.rana12"   "12691.rana33"
# [25] "12691.rana42"   "12691.rana39"   "12691.rana03"   "12691.rana30"
# [29] "12691.rana35"   "12691.rana31"   "12691.rana44"   "12691.rana11"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      16       0
#    Control    2      14
#
#                Accuracy : 0.9375
#                  95% CI : (0.7919, 0.9923)
#     No Information Rate : 0.5625
#     P-Value [Acc > NIR] : 3.289e-06
#
#                   Kappa : 0.875
#  Mcnemar's Test P-Value : 0.4795
#
#             Sensitivity : 0.8889
#             Specificity : 1.0000
#          Pos Pred Value : 1.0000
#          Neg Pred Value : 0.8750
#              Prevalence : 0.5625
#          Detection Rate : 0.5000
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.9444
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.2297188         0.9570312         0.8919151         0.9375000
#             Kappa                F1       Sensitivity       Specificity
#         0.8750000         0.9411765         1.0000000         0.8750000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8888889         1.0000000         0.8888889         1.0000000
#    Detection_Rate Balanced_Accuracy
#         0.5000000         0.9375000
# [1] "Sub-Sampling Iteration: 14/100"
#  [1] "12667.X3039009" "12667.X2060998" "12667.X2056691" "12667.X2048152"
#  [5] "12667.X2457964" "12667.X2068760" "12667.X2483184" "12667.X2472337"
#  [9] "12667.X2061574" "12667.X2496221" "12667.X2047268" "12667.X3076646"
# [13] "12667.X2036767" "12667.X2043129" "12667.X2049520" "12667.X2147547"
# [17] "12691.rana25"   "12691.rana61"   "12691.rana13"   "12691.rana60"
# [21] "12691.rana28"   "12691.rana50"   "12691.rana02"   "12691.rana10"
# [25] "12691.rana18"   "12691.rana44"   "12691.rana24"   "12691.rana09"
# [29] "12691.rana49"   "12691.rana37"   "12691.rana05"   "12691.rana43"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      14       2
#    Control    3      13
#
#                Accuracy : 0.8438
#                  95% CI : (0.6721, 0.9472)
#     No Information Rate : 0.5312
#     P-Value [Acc > NIR] : 0.000216
#
#                   Kappa : 0.6875
#  Mcnemar's Test P-Value : 1.000000
#
#             Sensitivity : 0.8235
#             Specificity : 0.8667
#          Pos Pred Value : 0.8750
#          Neg Pred Value : 0.8125
#              Prevalence : 0.5312
#          Detection Rate : 0.4375
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.8451
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.4448030         0.8554688         0.7707070         0.8437500
#             Kappa                F1       Sensitivity       Specificity
#         0.6875000         0.8484848         0.8750000         0.8125000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8235294         0.8666667         0.8235294         0.8750000
#    Detection_Rate Balanced_Accuracy
#         0.4375000         0.8437500
# [1] "Sub-Sampling Iteration: 15/100"
#  [1] "12667.X2059586" "12667.X2483184" "12667.X2047268" "12667.X3030973"
#  [5] "12667.X2061316" "12667.X2378267" "12667.X2170593" "12667.X2044156"
#  [9] "12667.X2062971" "12667.X2051138" "12667.X2067131" "12667.X2061359"
# [13] "12667.X2068980" "12667.X2052835" "12667.X2043400" "12667.X2058733"
# [17] "12691.rana14"   "12691.rana06"   "12691.rana02"   "12691.rana09"
# [21] "12691.rana31"   "12691.rana54"   "12691.rana35"   "12691.rana56"
# [25] "12691.rana60"   "12691.rana29"   "12691.rana05"   "12691.rana24"
# [29] "12691.rana13"   "12691.rana11"   "12691.rana49"   "12691.rana04"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      16       0
#    Control    2      14
#
#                Accuracy : 0.9375
#                  95% CI : (0.7919, 0.9923)
#     No Information Rate : 0.5625
#     P-Value [Acc > NIR] : 3.289e-06
#
#                   Kappa : 0.875
#  Mcnemar's Test P-Value : 0.4795
#
#             Sensitivity : 0.8889
#             Specificity : 1.0000
#          Pos Pred Value : 1.0000
#          Neg Pred Value : 0.8750
#              Prevalence : 0.5625
#          Detection Rate : 0.5000
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.9444
#
#        'Positive' Class : PRAD
#
#           logLoss               AUC             prAUC          Accuracy
#         0.2904751         0.9375000         0.8606290         0.9375000
#             Kappa                F1       Sensitivity       Specificity
#         0.8750000         0.9411765         1.0000000         0.8750000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8888889         1.0000000         0.8888889         1.0000000
#    Detection_Rate Balanced_Accuracy
#         0.5000000         0.9375000
# [1] "Sub-Sampling Iteration: 16/100"
#  [1] "12667.X2052835" "12667.X2047268" "12667.X2062843" "12667.X3034050"
#  [5] "12667.X2068980" "12667.X2051123" "12667.X3003105" "12667.X3039009"
#  [9] "12667.X2076870" "12667.X2062809" "12667.X2055755" "12667.X2488349"
# [13] "12667.X2036767" "12667.X2058733" "12667.X2483184" "12667.X2457964"
# [17] "12691.rana36"   "12691.rana59"   "12691.rana06"   "12691.rana60"
# [21] "12691.rana08"   "12691.rana37"   "12691.rana03"   "12691.rana26"
# [25] "12691.rana29"   "12691.rana04"   "12691.rana39"   "12691.rana42"
# [29] "12691.rana13"   "12691.rana40"   "12691.rana25"   "12691.rana16"
# [1] "LOOCV Iteration: 1/32"
# [1] "LOOCV Iteration: 2/32"
# [1] "LOOCV Iteration: 3/32"
# [1] "LOOCV Iteration: 4/32"
# [1] "LOOCV Iteration: 5/32"
# [1] "LOOCV Iteration: 6/32"
# [1] "LOOCV Iteration: 7/32"
# [1] "LOOCV Iteration: 8/32"
# [1] "LOOCV Iteration: 9/32"
# [1] "LOOCV Iteration: 10/32"
# [1] "LOOCV Iteration: 11/32"
# [1] "LOOCV Iteration: 12/32"
# [1] "LOOCV Iteration: 13/32"
# [1] "LOOCV Iteration: 14/32"
# [1] "LOOCV Iteration: 15/32"
# [1] "LOOCV Iteration: 16/32"
# [1] "LOOCV Iteration: 17/32"
# [1] "LOOCV Iteration: 18/32"
# [1] "LOOCV Iteration: 19/32"
# [1] "LOOCV Iteration: 20/32"
# [1] "LOOCV Iteration: 21/32"
# [1] "LOOCV Iteration: 22/32"
# [1] "LOOCV Iteration: 23/32"
# [1] "LOOCV Iteration: 24/32"
# [1] "LOOCV Iteration: 25/32"
# [1] "LOOCV Iteration: 26/32"
# [1] "LOOCV Iteration: 27/32"
# [1] "LOOCV Iteration: 28/32"
# [1] "LOOCV Iteration: 29/32"
# [1] "LOOCV Iteration: 30/32"
# [1] "LOOCV Iteration: 31/32"
# [1] "LOOCV Iteration: 32/32"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD Control
#    PRAD      14       2
#    Control    2      14
#
#                Accuracy : 0.875
#                  95% CI : (0.7101, 0.9649)
#     No Information Rate : 0.5
#     P-Value [Acc > NIR] : 9.651e-06
#
#                   Kappa : 0.75
#  Mcnemar's Test P-Value : 1
#
#             Sensitivity : 0.8750
#             Specificity : 0.8750
#          Pos Pred Value : 0.8750
#          Neg Pred Value : 0.8750
#              Prevalence : 0.5000
#          Detection Rate : 0.4375
#    Detection Prevalence : 0.5000
#       Balanced Accuracy : 0.8750
#
# ...
# 21  0.2088087 0.9843750 0.9226959  0.93750 0.8750 0.9375000      0.9375
# 22  0.4699252 0.8789062 0.8136239  0.84375 0.6875 0.8387097      0.8125
# 23  0.4663834 0.8710938 0.7863425  0.87500 0.7500 0.8666667      0.8125
# 24  0.2460017 0.9335938 0.8582342  0.93750 0.8750 0.9333333      0.8750
# 25  0.3302827 0.9414062 0.8773561  0.90625 0.8125 0.9090909      0.9375
# 26  0.4979016 0.8593750 0.7923308  0.81250 0.6250 0.8125000      0.8125
# 27  0.3579380 0.9296875 0.8686840  0.87500 0.7500 0.8750000      0.8750
# 28  0.4006798 0.8945312 0.8294310  0.90625 0.8125 0.9090909      0.9375
# 29  0.4506995 0.8984375 0.8293919  0.90625 0.8125 0.9090909      0.9375
# 30  0.5116042 0.8828125 0.8163003  0.84375 0.6875 0.8387097      0.8125
# 31  0.4284750 0.9296875 0.8546879  0.90625 0.8125 0.9032258      0.8750
# 32  0.4648848 0.8789062 0.8279151  0.75000 0.5000 0.7647059      0.8125
# 33  0.5044384 0.8281250 0.7578294  0.81250 0.6250 0.8235294      0.8750
# 34  0.1442620 0.9882812 0.9263571  0.96875 0.9375 0.9696970      1.0000
# 35  0.3937545 0.9101562 0.8363855  0.87500 0.7500 0.8666667      0.8125
0.9375      0.9375000      0.9375000 0.9375000 0.9375        0.46875
# 93       0.8125      0.8235294      0.8666667 0.8235294 0.8750        0.43750
# 94       0.9375      0.9375000      0.9375000 0.9375000 0.9375        0.46875
# 95       0.8750      0.8666667      0.8235294 0.8666667 0.8125        0.40625
# 96       0.7500      0.7647059      0.8000000 0.7647059 0.8125        0.40625
# 97       0.8750      0.8750000      0.8750000 0.8750000 0.8750        0.43750
# 98       0.8125      0.8125000      0.8125000 0.8125000 0.8125        0.40625
# 99       0.8750      0.8750000      0.8750000 0.8750000 0.8750        0.43750
# 100      0.8750      0.8823529      0.9333333 0.8823529 0.9375        0.46875
#     Balanced_Accuracy
# 1             0.87500
# 2             0.90625
# 3             0.84375
# 4             0.96875
# 5             0.90625
# 6             0.87500
# 7             0.87500
# 8             0.90625
# 9             0.81250
# 10            0.81250
# 11            0.90625
# 12            0.81250
# 13            0.93750
# 14            0.84375
# 15            0.93750
# 16            0.87500
# 17            0.75000
# 18            0.90625
# 19            0.96875
# 20            0.90625
# 21            0.93750
# 22            0.84375
# 23            0.87500
# 24            0.93750
# 25            0.90625
# 26            0.81250
# 27            0.87500
# 28            0.90625
# 29            0.90625
# 30            0.84375
# 31            0.90625
# 32            0.75000
# 33            0.81250
# 34            0.96875
# 35            0.87500
# 36            0.75000
# 37            0.87500
# 38            0.90625
# 39            0.84375
# 40            0.93750
# 41            0.93750
# 42            0.93750
# 43            0.93750
# 44            0.84375
# 45            0.87500
# 46            0.90625
# 47            0.87500
# 48            0.93750
# 49            0.84375
# 50            0.87500
# 51            0.96875
# 52            0.75000
# 53            0.84375
# 54            0.87500
# 55            0.90625
# 56            0.84375
# 57            0.84375
# 58            0.84375
# 59            0.78125
# 60            0.84375
# 61            0.90625
# 62            0.78125
# 63            0.87500
# 64            0.93750
# 65            0.84375
# 66            0.84375
# 67            0.93750
# 68            0.81250
# 69            0.84375
# 70            0.87500
# 71            0.84375
# 72            0.90625
# 73            0.84375
# 74            0.81250
# 75            0.93750
# 76            0.90625
# 77            0.71875
# 78            0.81250
# 79            0.87500
# 80            0.93750
# 81            0.90625
# 82            0.81250
# 83            0.81250
# 84            0.84375
# 85            0.84375
# 86            0.81250
# 87            0.90625
# 88            0.78125
# 89            0.75000
# 90            0.90625
# 91            0.78125
# 92            0.93750
# 93            0.84375
# 94            0.93750
# 95            0.84375
# 96            0.78125
# 97            0.87500
# 98            0.81250
# 99            0.87500
# 100           0.90625
# Error in roc.default(response, predictor, ...) : No valid data provided.

# %%
# %%R
# nsclc_control_ss16 <- loocvDTs_subsample(snmData = snmDataKrakenCFDecontamDPQC,
#                                         samplingSize = 16,
#                                         iterSize = 100,
#                                         DTs = c("NSCLC","Control"),
#                                         caretTuneGrid = defaultGBMGrid)
# save(nsclc_control_ss16, file = "nsclc_control_ss16_100.RData")

# %%
# %%R
# skcm_control_ss16 <- loocvDTs_subsample(snmData = snmDataKrakenCFDecontamDPQC,
#                                          samplingSize = 16,
#                                          iterSize = 100,
#                                          DTs = c("SKCM","Control"),
#                                          caretTuneGrid = defaultGBMGrid)
# save(skcm_control_ss16, file = "skcm_control_ss16_100.RData")
