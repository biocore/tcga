# %%
import os, numpy, warnings
import pandas as pd

# %%
os.environ['R_HOME'] = '/home/gdpoore/anaconda3/envs/tcgaAnalysisPythonR/lib/R'
warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format = 'retina'

# %%
# %reload_ext rpy2.ipython

# %%
# %%R
#
# require(ggplot2)
# require(snm)
# require(limma)
# require(edgeR)
# require(dplyr)
# require(edgeR)
# require(pvca)
# require(lme4)
# require(ggsci)
# require(cowplot)
# require(doMC)
# require(splitstackshape)
#
# numCores <- detectCores()
# registerDoMC(cores=numCores)

# %%
# %%R
# load("snmCfdnaShogunAndMetadata_Dec2_Final.RData")
# load("snmKrakenAndMetadataFiltered_Dec2_Final.RData")

# %%
# %%R
# # Load dependencies
# require(devtools)
# require(doMC)
# require(tibble)
# require(gbm)
# require(splitstackshape)
# require(reshape2)
# require(ggpubr)
# require(caret) # for model building
# require(pROC) # for AUC calculations
# require(purrr) # for functional programming using map()
# require(dplyr) # for data manipulation
# require(doMC) # for parallel computing
# require(gbm) # for machine learning
# require(tibble) # for df operations
# require(cowplot) # for plotting
# require(PRROC) # for precision-recall curves
# require(MLmetrics) # for multi-class learning
# require(caret) # for machine learning
#
# defaultGBMGrid <-  expand.grid(interaction.depth = seq(1,3),
#                                n.trees = floor((1:3) * 50),
#                                shrinkage = 0.1,
#                                n.minobsinnode = 5)
# customGBMGrid <-  expand.grid(interaction.depth = seq(1,3),
#                               n.trees = floor((1:3) * 50),
#                               shrinkage = 0.1,
#                               n.minobsinnode = 1)
# numKFold <- 4
# numResampleIter <- 1
#
# ml2DTs <- function(snmData,
#                    classOfInterest = "Lung Adenocarcinoma",
#                    cutPoint = 0.5,
#                    samplingSize = 20,
#                    caretTuneGrid = defaultGBMGrid){
#
#   metaTmp1 <- droplevels(metadataPSMatchedDPQCFiltered[(metadataPSMatchedDPQCFiltered$disease_type_consol %in% c("PRAD",
#                                                                                                              "SKCM",
#                                                                                                              "NSCLC")),])
#   tmp <- metaTmp1
#   tmp$disease_type_consol <- factor(ifelse(metaTmp1$disease_type_consol == classOfInterest, yes = classOfInterest, no = "Other"))
#   metadataSimSampled <- as.data.frame(stratified(tmp,
#                                                  group = "disease_type_consol",
#                                                  size = samplingSize,
#                                                  keep.rownames = TRUE,
#                                                  replace = FALSE,
#                                                  bothSets = FALSE))
#   rownames(metadataSimSampled) <- metadataSimSampled$rn
#   mlDataY <- metadataSimSampled
#   mlDataX <- snmData[rownames(mlDataY),]
#
#   set.seed(42)
#   index <- createDataPartition(mlDataY$disease_type_consol, p = 0.7, list = FALSE)
#   trainX <- mlDataX[index,]
#   trainY <- mlDataY[index,]$disease_type_consol
#   testX <- mlDataX[-index,]
#   testY <- mlDataY[-index,]$disease_type_consol
#   # print(testY)
#
#   refactoredTrainY <- factor(gsub('([[:punct:]])|\\s+','',trainY))
#   refactoredTestY <- factor(gsub('([[:punct:]])|\\s+','',testY))
#
#   set.seed(42)
#   ctrl <- trainControl(method = "repeatedcv",
#                        number = numKFold,
#                        repeats = numResampleIter,
#                        sampling = "up",
#                        summaryFunction = twoClassSummary,
#                        classProbs = TRUE,
#                        verboseIter = TRUE,
#                        savePredictions = TRUE,
#                        allowParallel=TRUE)
#
#   mlModel <- train(x = trainX,
#                    y = refactoredTrainY,
#                    method = "gbm",
#                    preProcess = c("scale","center"),
#                    trControl = ctrl,
#                    verbose = TRUE,
#                    metric = "ROC",
#                    tuneGrid = customGBMGrid)
#
#   positiveClass <- gsub(" ","", classOfInterest)
#   negativeClass <- "Other"
#
#   predProbs <- as.numeric(predict(mlModel, newdata = testX, type = "prob")[,positiveClass])
#   fg <- predProbs[refactoredTestY == positiveClass]
#   bg <- predProbs[refactoredTestY == negativeClass]
#
#   prroc_roc <- roc.curve(scores.class0 = fg, scores.class1 = bg, curve = T)
#   prroc_pr <- pr.curve(scores.class0 = fg, scores.class1 = bg, curve = T, rand.compute=T)
#
#   # par(mfrow = c(1,2))
#   plot(prroc_roc)
#   plot(prroc_pr)
#   # dev.off()
#
#
#   predClass <- predict(mlModel, newdata = testX)
#
#   confusionMatrix(table(predict(mlModel, newdata = testX, type="prob")[,positiveClass] >= cutPoint,
#                         refactoredTestY == positiveClass))
# }
#
# #-----------------------------------------#
# # Machine learning
# #-----------------------------------------#
#
#
# # mlHvsC <- function(snmData){
# # Load dependencies
#
#
# mlHvsC <- function(snmData){
#
#   numCores <- detectCores()
#   registerDoMC(cores=numCores)
#
#   defaultGBMGrid <-  expand.grid(interaction.depth = seq(1,3),
#                                  n.trees = floor((1:3) * 50),
#                                  shrinkage = 0.1,
#                                  n.minobsinnode = 5)
#   customGBMGrid <-  expand.grid(interaction.depth = seq(1,3),
#                                 n.trees = floor((1:3) * 50),
#                                 shrinkage = 0.1,
#                                 n.minobsinnode = 1)
#
#   caretTuneGrid <- defaultGBMGrid
#   numKFold <- 4
#   numResampleIter <- 1
#
#   mlDataY <- metadataPSMatchedDPQCFiltered
#   mlDataX <- snmData[rownames(mlDataY),]
#
#   set.seed(42)
#   index <- createDataPartition(mlDataY$HvsC, p = 0.7, list = FALSE)
#   trainX <- mlDataX[index,]
#   trainY <- mlDataY[index,]$HvsC
#   testX <- mlDataX[-index,]
#   testY <- mlDataY[-index,]$HvsC
#   # print(testY)
#
#   refactoredTrainY <- factor(gsub('([[:punct:]])|\\s+','',trainY))
#   refactoredTestY <- factor(gsub('([[:punct:]])|\\s+','',testY))
#
#   set.seed(42)
#   ctrl <- trainControl(method = "repeatedcv",
#                        number = numKFold,
#                        repeats = numResampleIter,
#                        sampling = "up",
#                        summaryFunction = twoClassSummary,
#                        classProbs = TRUE,
#                        verboseIter = TRUE,
#                        savePredictions = TRUE,
#                        allowParallel=TRUE)
#
#   mlModel <- train(x = trainX,
#                    y = refactoredTrainY,
#                    method = "gbm",
#                    preProcess = c("scale","center"),
#                    trControl = ctrl,
#                    verbose = TRUE,
#                    metric = "ROC",
#                    tuneGrid = defaultGBMGrid)
#
#   positiveClass <- "Cancer"
#   negativeClass <- "Control"
#   predProbs <- as.numeric(predict(mlModel, newdata = testX, type = "prob")[,positiveClass])
#   fg <- predProbs[refactoredTestY == positiveClass]
#   bg <- predProbs[refactoredTestY == negativeClass]
#
#   prroc_roc <- roc.curve(scores.class0 = fg, scores.class1 = bg, curve = T)
#   prroc_pr <- pr.curve(scores.class0 = fg, scores.class1 = bg, curve = T, rand.compute=T)
#
#   plot(prroc_roc)
#   plot(prroc_pr)
#
#   predClass <- predict(mlModel, newdata = testX)
#   print(confusionMatrix(data = predClass, reference = refactoredTestY, positive = positiveClass))
# }
#
# #-----------------------------------------------------
#
# loocvDTs <- function(snmData, samplingSize = 15, DTs, caretTuneGrid = defaultGBMGrid,
#                      filenameString = paste(DTs,collapse = "__"), HvsCFlag = FALSE){
#
#   if(HvsCFlag){
#     metaTmpX <- droplevels(metadataPSMatchedDPQCFiltered[(metadataPSMatchedDPQCFiltered$disease_type_consol %in% DTs),])
#     metaTmpX$disease_type_consol <- metaTmpX$HvsC
#     classes <- gsub(" ","",levels(metaTmpX$disease_type_consol))
#   } else{
#     metaTmpX <- droplevels(metadataPSMatchedDPQCFiltered[(metadataPSMatchedDPQCFiltered$disease_type_consol %in% DTs),])
#     classes <- gsub(" ","",DTs)
#   }
#
#   # Do LOOCV model building and testing
#
#   multiClassSummaryStats <- list()
#   multiClassSummaryStatsDist <- list()
#   numKFold <- 4
#   numResampleIter <- 1
#   metaData <- metaTmpX
#   snmData <- snmData # dataPSUniqueDecontamQC #
#   iterSize <- 1
#   for(jj in 1:iterSize){
#     metadataSimSampled <- as.data.frame(stratified(metaData,
#                                                    group = "disease_type_consol",
#                                                    size = samplingSize,
#                                                    keep.rownames = TRUE,
#                                                    replace = FALSE,
#                                                    bothSets = FALSE))
#     rownames(metadataSimSampled) <- metadataSimSampled$rn
#     mlDataY <- metadataSimSampled
#     mlDataX <- snmData[rownames(mlDataY),]
#     dim(mlDataY)[1] == dim(mlDataX)[1] # Sanity check
#
#     # Create data partitions
#     # set.seed(42)
#     indexSuper <- 1:dim(mlDataY)[1]
#     predProbs <- list()
#     obsClass <- vector()
#     predClass <- vector()
#     varImpBestModelDF2OrderedNonzeroList <- list()
#
#     for(ii in 1:length(indexSuper)){
#       print(sprintf("Iteration: %d/%d", ii, length(indexSuper)))
#       index <- indexSuper[ii]
#       # print(index)
#       trainX <- mlDataX[-index,]
#       trainY <- mlDataY[-index,]$disease_type_consol
#       testX <- mlDataX[index,,drop=FALSE]
#       testY <- mlDataY[index,,drop=FALSE]$disease_type_consol
#       # print(testY)
#
#       refactoredTrainY <- factor(gsub('([[:punct:]])|\\s+','',trainY))
#       refactoredTestY <- factor(gsub('([[:punct:]])|\\s+','',testY))
#
#       obsClass[ii] <- as.character(refactoredTestY)
#
#       set.seed(42)
#       ctrl <- trainControl(method = "repeatedcv",
#                            number = numKFold,
#                            repeats = numResampleIter,
#                            sampling = "up",
#                            summaryFunction = multiClassSummary,
#                            classProbs = TRUE,
#                            verboseIter = FALSE,
#                            savePredictions = TRUE,
#                            allowParallel=TRUE)
#
#       mlModel <- train(x = trainX,
#                        y = refactoredTrainY,
#                        method = "gbm",
#                        preProcess = c("scale","center"),
#                        trControl = ctrl,
#                        verbose = FALSE,
#                        metric = "ROC",
#                        tuneGrid = caretTuneGrid)
#
#       predProbs[ii] <- list(predict(mlModel, newdata = testX, type = "prob"))
#       predClass[ii] <- as.character(predict(mlModel, newdata = testX, type = "raw"))
#
#       varImpBestModelDF <- as.data.frame(varImp( mlModel$finalModel, scale = FALSE ))
#       varImpBestModelDF2 <- rownames_to_column(varImpBestModelDF, "Taxa")
#       varImpBestModelDF2Ordered <- varImpBestModelDF2[order(-varImpBestModelDF2$Overall),]
#       colnames(varImpBestModelDF2Ordered)[2] <- "varImp"
#       varImpBestModelDF2OrderedNonzero <- varImpBestModelDF2Ordered[varImpBestModelDF2Ordered$varImp != 0,]
#       varImpBestModelDF2OrderedNonzeroList[[ii]] <- varImpBestModelDF2OrderedNonzero
#
#       rm(mlModel)
#     }
#
#     loocvPreds <- cbind(obs = factor(obsClass,
#                                      levels = classes),
#                         pred = factor(predClass,
#                                       levels = classes),
#                         do.call(rbind,predProbs))
#     # multiClassSummaryStats <- multiClassSummary(loocvPreds, lev = classes)
#     # print(multiClassSummaryStats)
#
#     multiClassSummaryStats[[jj]] <- multiClassSummary(loocvPreds, lev = classes)
#     print(multiClassSummaryStats[[jj]])
#
#     filenameROC <- paste0(filenameString,"__SHOGUN__ROC.png")
#     filenamePR <- paste0(filenameString,"__SHOGUN__PR.png")
#     filenameROCData <- paste0(filenameString,"__SHOGUN__Data__ROC.csv")
#     filenamePRData <- paste0(filenameString,"__SHOGUN__Data__PR.csv")
#     filenameSink <- paste0(filenameString,"__SHOGUN__CM.txt")
#
#     predProbs <- loocvPreds[,DTs[1]]
#     fg <- predProbs[loocvPreds$obs == DTs[1]]
#     bg <- predProbs[loocvPreds$obs == DTs[2]]
#
#     prroc_roc <- roc.curve(scores.class0 = fg, scores.class1 = bg, curve = T)
#     prroc_pr <- pr.curve(scores.class0 = fg, scores.class1 = bg, curve = T, rand.compute=T)
#
#     png(filename=filenameROC, width = 6, height = 4, units = 'in', res = 300)
#     plot(prroc_roc)
#     dev.off()
#
#     png(filename=filenamePR, width = 6, height = 4, units = 'in', res = 300)
#     plot(prroc_pr)
#     dev.off()
#
#     rocCurveData <- cbind(as.data.frame(prroc_roc$curve), DT1 = DTs[1], DT2 = DTs[2])
#     prCurveData <- cbind(as.data.frame(prroc_pr$curve), DT1 = DTs[1], DT2 = DTs[2])
#
#     write.table(prCurveData, sep=",", file = filenamePRData, col.names = FALSE)
#     write.table(rocCurveData, sep=",", file = filenameROCData, col.names = FALSE)
#   }
#
#   print(confusionMatrix(loocvPreds$obs, loocvPreds$pred))
#   multiClassSummaryStatsDist <- data.frame(do.call(rbind, multiClassSummaryStats))
#
#   sink(filenameSink)
#   print(print(confusionMatrix(loocvPreds$obs, loocvPreds$pred)))
#   sink()
# }
#
# #-----------------------------------------------------
#
# ml2DTs <- function(snmData,
#                    classOfInterest = "Lung Adenocarcinoma",
#                    cutPoint = 0.5,
#                    samplingSize = 20,
#                    caretTuneGrid = defaultGBMGrid){
#
#   metaTmp1 <- droplevels(metadataPSMatchedDPQCFiltered[(metadataPSMatchedDPQCFiltered$disease_type_consol %in% c("PRAD",
#                                                                                                              "SKCM",
#                                                                                                              "NSCLC")),])
#   tmp <- metaTmp1
#   tmp$disease_type_consol <- factor(ifelse(metaTmp1$disease_type_consol == classOfInterest, yes = classOfInterest, no = "Other"))
#   metadataSimSampled <- as.data.frame(stratified(tmp,
#                                                  group = "disease_type_consol",
#                                                  size = samplingSize,
#                                                  keep.rownames = TRUE,
#                                                  replace = FALSE,
#                                                  bothSets = FALSE))
#   rownames(metadataSimSampled) <- metadataSimSampled$rn
#   mlDataY <- metadataSimSampled
#   mlDataX <- snmData[rownames(mlDataY),]
#
#   set.seed(42)
#   index <- createDataPartition(mlDataY$disease_type_consol, p = 0.7, list = FALSE)
#   trainX <- mlDataX[index,]
#   trainY <- mlDataY[index,]$disease_type_consol
#   testX <- mlDataX[-index,]
#   testY <- mlDataY[-index,]$disease_type_consol
#   # print(testY)
#
#   refactoredTrainY <- factor(gsub('([[:punct:]])|\\s+','',trainY))
#   refactoredTestY <- factor(gsub('([[:punct:]])|\\s+','',testY))
#
#   set.seed(42)
#   ctrl <- trainControl(method = "repeatedcv",
#                        number = numKFold,
#                        repeats = numResampleIter,
#                        sampling = "up",
#                        summaryFunction = twoClassSummary,
#                        classProbs = TRUE,
#                        verboseIter = TRUE,
#                        savePredictions = TRUE,
#                        allowParallel=TRUE)
#
#   mlModel <- train(x = trainX,
#                    y = refactoredTrainY,
#                    method = "gbm",
#                    preProcess = c("scale","center"),
#                    trControl = ctrl,
#                    verbose = TRUE,
#                    metric = "ROC",
#                    tuneGrid = customGBMGrid)
#
#   positiveClass <- gsub(" ","", classOfInterest)
#   negativeClass <- "Other"
#
#   predProbs <- as.numeric(predict(mlModel, newdata = testX, type = "prob")[,positiveClass])
#   fg <- predProbs[refactoredTestY == positiveClass]
#   bg <- predProbs[refactoredTestY == negativeClass]
#
#   prroc_roc <- roc.curve(scores.class0 = fg, scores.class1 = bg, curve = T)
#   prroc_pr <- pr.curve(scores.class0 = fg, scores.class1 = bg, curve = T, rand.compute=T)
#
#   # par(mfrow = c(1,2))
#   plot(prroc_roc)
#   plot(prroc_pr)
#   # dev.off()
#
#
#   predClass <- predict(mlModel, newdata = testX)
#
#   confusionMatrix(table(predict(mlModel, newdata = testX, type="prob")[,positiveClass] >= cutPoint,
#                         refactoredTestY == positiveClass))
# }

# %%
# %%R
# hVsC4 <- loocvDTs(snmData = snmShogundataPSUniqueDecontamDPQC,
#                  samplingSize = 100,
#                  DTs = c("Control","SKCM", "PRAD", "NSCLC"),
#                  caretTuneGrid = defaultGBMGrid, HvsCFlag = TRUE)
# Out:
# [1] "Iteration: 1/169"
# [1] "Iteration: 2/169"
# [1] "Iteration: 3/169"
# [1] "Iteration: 4/169"
# [1] "Iteration: 5/169"
# [1] "Iteration: 6/169"
# [1] "Iteration: 7/169"
# [1] "Iteration: 8/169"
# [1] "Iteration: 9/169"
# [1] "Iteration: 10/169"
# [1] "Iteration: 11/169"
# [1] "Iteration: 12/169"
# [1] "Iteration: 13/169"
# [1] "Iteration: 14/169"
# [1] "Iteration: 15/169"
# [1] "Iteration: 16/169"
# [1] "Iteration: 17/169"
# [1] "Iteration: 18/169"
# [1] "Iteration: 19/169"
# [1] "Iteration: 20/169"
# [1] "Iteration: 21/169"
# [1] "Iteration: 22/169"
# [1] "Iteration: 23/169"
# [1] "Iteration: 24/169"
# [1] "Iteration: 25/169"
# [1] "Iteration: 26/169"
# [1] "Iteration: 27/169"
# [1] "Iteration: 28/169"
# [1] "Iteration: 29/169"
# [1] "Iteration: 30/169"
# [1] "Iteration: 31/169"
# [1] "Iteration: 26/85"
# [1] "Iteration: 27/85"
# [1] "Iteration: 28/85"
# [1] "Iteration: 29/85"
# [1] "Iteration: 30/85"
# [1] "Iteration: 31/85"
# [1] "Iteration: 32/85"
# [1] "Iteration: 33/85"
# [1] "Iteration: 34/85"
# [1] "Iteration: 35/85"
# [1] "Iteration: 36/85"
# [1] "Iteration: 37/85"
# [1] "Iteration: 38/85"
# [1] "Iteration: 39/85"
# [1] "Iteration: 40/85"
# [1] "Iteration: 41/85"
# [1] "Iteration: 42/85"
# [1] "Iteration: 43/85"
# [1] "Iteration: 44/85"
# [1] "Iteration: 45/85"
# [1] "Iteration: 46/85"
# [1] "Iteration: 47/85"
# [1] "Iteration: 48/85"
# [1] "Iteration: 49/85"
# [1] "Iteration: 50/85"
# [1] "Iteration: 51/85"
# [1] "Iteration: 52/85"
# [1] "Iteration: 53/85"
# [1] "Iteration: 54/85"
# [1] "Iteration: 55/85"
# [1] "Iteration: 56/85"
# [1] "Iteration: 57/85"
# [1] "Iteration: 58/85"
# [1] "Iteration: 59/85"
# [1] "Iteration: 60/85"
# [1] "Iteration: 61/85"
# [1] "Iteration: 62/85"
# [1] "Iteration: 63/85"
# [1] "Iteration: 64/85"
# [1] "Iteration: 65/85"
# [1] "Iteration: 66/85"
# [1] "Iteration: 67/85"
# [1] "Iteration: 68/85"
# [1] "Iteration: 69/85"
# [1] "Iteration: 70/85"
# [1] "Iteration: 71/85"
# [1] "Iteration: 72/85"
# [1] "Iteration: 73/85"
# [1] "Iteration: 74/85"
# [1] "Iteration: 75/85"
# [1] "Iteration: 76/85"
# [1] "Iteration: 77/85"
# [1] "Iteration: 78/85"
# [1] "Iteration: 79/85"
# [1] "Iteration: 80/85"
# [1] "Iteration: 81/85"
# [1] "Iteration: 82/85"
# [1] "Iteration: 83/85"
# [1] "Iteration: 84/85"
# [1] "Iteration: 85/85"
#           logLoss               AUC             prAUC          Accuracy
#        0.42174233        0.75543478        0.65793957        0.82352941
#             Kappa                F1       Sensitivity       Specificity
#        0.37774524        0.48275862        0.43750000        0.91304348
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#        0.53846154        0.87500000        0.53846154        0.43750000
#    Detection_Rate Balanced_Accuracy
#        0.08235294        0.67527174
# Confusion Matrix and Statistics
#
#           Reference
# Prediction SKCM Control
#    SKCM       7       9
#    Control    6      63
#
#                Accuracy : 0.8235
#                  95% CI : (0.7257, 0.8977)
#     No Information Rate : 0.8471
#     P-Value [Acc > NIR] : 0.7790
#
#                   Kappa : 0.3777
#  Mcnemar's Test P-Value : 0.6056
#
#             Sensitivity : 0.53846
#             Specificity : 0.87500
#          Pos Pred Value : 0.43750
#          Neg Pred Value : 0.91304
#              Prevalence : 0.15294
#          Detection Rate : 0.08235
#    Detection Prevalence : 0.18824
#       Balanced Accuracy : 0.70673
#
#        'Positive' Class : SKCM

# %%
# %%R
# prad_nsclc <- loocvDTs(snmData = snmShogundataPSUniqueDecontamDPQC,
#                  samplingSize = 59,
#                  DTs = c("PRAD","NSCLC"),
#                  caretTuneGrid = defaultGBMGrid)
# Out:
# [1] "Iteration: 1
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD NSCLC
#      PRAD    56     3
#      NSCLC    8    17
#
#                Accuracy : 0.869
#                  95% CI : (0.7778, 0.9328)
#     No Information Rate : 0.7619
#     P-Value [Acc > NIR] : 0.01109
#
#                   Kappa : 0.6676
#  Mcnemar's Test P-Value : 0.22780
#
#             Sensitivity : 0.8750
#             Specificity : 0.8500
#          Pos Pred Value : 0.9492
#          Neg Pred Value : 0.6800
#              Prevalence : 0.7619
#          Detection Rate : 0.6667
#    Detection Prevalence : 0.7024
#       Balanced Accuracy : 0.8625
#
#        'Positive' Class : PRAD

# %%
# %%R
# nsclc_skcm <- loocvDTs(snmData = snmShogundataPSUniqueDecontamDPQC,
#                  samplingSize = 25,
#                  DTs = c("NSCLC","SKCM"),
#                  caretTuneGrid = defaultGBMGrid)
# Out:
# [1] "Iteration: 1/41"
# [1] "Iteration: 2/41"
# [1] "Iteration: 3/41"
# [1] "Iteration: 4/41"
# [1] "Iteration: 5/41"
# [1] "Iteration: 6/41"
# [1] "Iteration: 7/41"
# [1] "Iteration: 8/41"
# [1] "Iteration: 9/41"
# [1] "Iteration: 10/41"
# [1] "Iteration: 11/41"
# [1] "Iteration: 12/41"
# [1] "Iteration: 13/41"
# [1] "Iteration: 14/41"
# [1] "Iteration: 15/41"
# [1] "Iteration: 16/41"
# [1] "Iteration: 17/41"
# [1] "Iteration: 18/41"
# [1] "Iteration: 19/41"
# [1] "Iteration: 20/41"
# [1] "Iteration: 21/41"
# [1] "Iteration: 22/41"
# [1] "Iteration: 23/41"
# [1] "Iteration: 24/41"
# [1] "Iteration: 25/41"
# [1] "Iteration: 26/41"
# [1] "Iteration: 27/41"
# [1] "Iteration: 28/41"
# [1] "Iteration: 29/41"
# [1] "Iteration: 30/41"
# [1] "Iteration: 31/41"
# [1] "Iteration: 32/41"
# [1] "Iteration: 33/41"
# [1] "Iteration: 34/41"
# [1] "Iteration: 35/41"
# [1] "Iteration: 36/41"
# [1] "Iteration: 37/41"
# [1] "Iteration: 38/41"
# [1] "Iteration: 39/41"
# [1] "Iteration: 40/41"
# [1] "Iteration: 41/41"
#           logLoss               AUC             prAUC          Accuracy
#         0.5133010         0.8050000         0.7739967         0.8292683
#             Kappa                F1       Sensitivity       Specificity
#         0.6287193         0.8679245         0.9200000         0.6875000
#    Pos_Pred_Value    Neg_Pred_Value         Precision            Recall
#         0.8214286         0.8461538         0.8214286         0.9200000
#    Detection_Rate Balanced_Accuracy
#         0.5609756         0.8037500
# Confusion Matrix and Statistics
#
#           Reference
# Prediction NSCLC SKCM
#      NSCLC    23    2
#      SKCM      5   11
#
#                Accuracy : 0.8293
#                  95% CI : (0.6794, 0.9285)
#     No Information Rate : 0.6829
#     P-Value [Acc > NIR] : 0.02781
#
#                   Kappa : 0.6287
#  Mcnemar's Test P-Value : 0.44969
#
#             Sensitivity : 0.8214
#             Specificity : 0.8462
#          Pos Pred Value : 0.9200
#          Neg Pred Value : 0.6875
#              Prevalence : 0.6829
#          Detection Rate : 0.5610
#    Detection Prevalence : 0.6098
#       Balanced Accuracy : 0.8338
#
#        'Positive' Class : NSCLC

# %%
# %%R
# prad_skcm <- loocvDTs(snmData = snmShogundataPSUniqueDecontamDPQC,
#                  samplingSize = 59,
#                  DTs = c("PRAD","SKCM"),
#                  caretTuneGrid = defaultGBMGrid)
# Out:
# [1] "Iteration: 1
# [1] "Iteration: 88/100"
# [1] "Iteration: 89/100"
# [1] "Iteration: 90/100"
# [1] "Iteration: 91/100"
# [1] "Iteration: 92/100"
# [1] "Iteration: 93/100"
# [1] "Iteration: 94/100"
# [1] "Iteration: 95/100"
# [1] "Iteration: 96/100"
# [1] "Iteration: 97/100"
# [1] "Iteration: 98/100"
# [1] "Iteration: 99/100"
# [1] "Iteration: 100/100"
#                logLoss                    AUC                  prAUC
#              0.7250187              0.8099672              0.6155596
#               Accuracy                  Kappa                Mean_F1
#              0.7100000              0.4801936              0.6290135
#       Mean_Sensitivity       Mean_Specificity    Mean_Pos_Pred_Value
#              0.6228531              0.8284359              0.6375179
#    Mean_Neg_Pred_Value         Mean_Precision            Mean_Recall
#              0.8316342              0.6375179              0.6228531
#    Mean_Detection_Rate Mean_Balanced_Accuracy
#              0.2366667              0.7256445
# Confusion Matrix and Statistics
#
#           Reference
# Prediction PRAD NSCLC SKCM
#      PRAD    48     2    9
#      NSCLC    6    17    2
#      SKCM     7     3    6
#
# Overall Statistics
#
#                Accuracy : 0.71
#                  95% CI : (0.6107, 0.7964)
#     No Information Rate : 0.61
#     P-Value [Acc > NIR] : 0.02415
#
#                   Kappa : 0.4802
#  Mcnemar's Test P-Value : 0.48440
#
# Statistics by Class:
#
#                      Class: PRAD Class: NSCLC Class: SKCM
# Sensitivity               0.7869       0.7727      0.3529
# Specificity               0.7179       0.8974      0.8795
# Pos Pred Value            0.8136       0.6800      0.3750
# Neg Pred Value            0.6829       0.9333      0.8690
# Prevalence                0.6100       0.2200      0.1700
# Detection Rate            0.4800       0.1700      0.0600
# Detection Prevalence      0.5900       0.2500      0.1600
# Balanced Accuracy         0.7524       0.8351      0.6162

# %%
# %%R
# DTH4 <- loocvDTs(snmData = snmShogundataPSUniqueDecontamDPQC,
#                  samplingSize = 69,
#                  DTs = c("Control","PRAD","NSCLC","SKCM"),
#                  caretTuneGrid = defaultGBMGrid)
# Out:
# [1] "Iteration: 1/169"
# [1] "Iteration: 2/169"
# [1] "Iteration: 3/169"
# [1] "Iteration: 4/169"
# [1] "Iteration: 5/169"
# [1] "Iteration: 6/169"
# [1] "Iteration: 7/169"
# [1] "Iteration: 8/169"
# [1] "Iteration: 9/169"
# [1] "Iteration: 10/169"
# [1] "Iteration: 11/169"
# [1] "Iteration: 12/169"
# [1] "Iteration: 13/169"
# [1] "Iteration: 14/169"
# [1] "Iteration: 15/169"
# [1] "Iteration: 16/169"
# [1] "Iteration: 17/169"
# [1] "Iteration: 18/169"
# [1] "Iteration: 19/169"
# [1] "Iteration: 20/169"
# [1] "Iteration: 21/169"
# [1] "Iteration: 22/169"
# [1] "Iteration: 23/169"
# [1] "Iteration: 24/169"
# [1] "Iteration: 25/169"
# [1] "Iteration: 26/169"
# [1] "Iteration: 27/169"
# [1] "Iteration: 28/169"
# [1] "Iteration: 29/169"
# [1] "Iteration: 30/169"
# [1] "Iteration: 31/169"
# [1] "Iteration: 32/169"
# [1] "Iteration: 33/169"
# [1] "Iteration: 34/169"
# [1] "Iteration: 35/169"
# [1] "Iteration: 36/169"
# [1] "Iteration: 37/169"
# [1] "Iteration: 38/169"
# [1] "Iteration: 133/169"
# [1] "Iteration: 134/169"
# [1] "Iteration: 135/169"
# [1] "Iteration: 136/169"
# [1] "Iteration: 137/169"
# [1] "Iteration: 138/169"
# [1] "Iteration: 139/169"
# [1] "Iteration: 140/169"
# [1] "Iteration: 141/169"
# [1] "Iteration: 142/169"
# [1] "Iteration: 143/169"
# [1] "Iteration: 144/169"
# [1] "Iteration: 145/169"
# [1] "Iteration: 146/169"
# [1] "Iteration: 147/169"
# [1] "Iteration: 148/169"
# [1] "Iteration: 149/169"
# [1] "Iteration: 150/169"
# [1] "Iteration: 151/169"
# [1] "Iteration: 152/169"
# [1] "Iteration: 153/169"
# [1] "Iteration: 154/169"
# [1] "Iteration: 155/169"
# [1] "Iteration: 156/169"
# [1] "Iteration: 157/169"
# [1] "Iteration: 158/169"
# [1] "Iteration: 159/169"
# [1] "Iteration: 160/169"
# [1] "Iteration: 161/169"
# [1] "Iteration: 162/169"
# [1] "Iteration: 163/169"
# [1] "Iteration: 164/169"
# [1] "Iteration: 165/169"
# [1] "Iteration: 166/169"
# [1] "Iteration: 167/169"
# [1] "Iteration: 168/169"
# [1] "Iteration: 169/169"
#                logLoss                    AUC                  prAUC
#              0.8236577              0.8252033              0.5893656
#               Accuracy                  Kappa                Mean_F1
#              0.7100592              0.5727479              0.6203162
#       Mean_Sensitivity       Mean_Specificity    Mean_Pos_Pred_Value
#              0.6200583              0.8961349              0.6219920
#    Mean_Neg_Pred_Value         Mean_Precision            Mean_Recall
#              0.8969227              0.6219920              0.6200583
#    Mean_Detection_Rate Mean_Balanced_Accuracy
#              0.1775148              0.7580966
# Confusion Matrix and Statistics
#
#           Reference
# Prediction Control PRAD NSCLC SKCM
#    Control      52   10     4    3
#    PRAD          5   47     2    5
#    NSCLC         2    4    17    2
#    SKCM          7    3     2    4
#
# Overall Statistics
#
#                Accuracy : 0.7101
#                  95% CI : (0.6354, 0.7772)
#     No Information Rate : 0.3905
#     P-Value [Acc > NIR] : <2e-16
#
#                   Kappa : 0.5727
#  Mcnemar's Test P-Value : 0.5311
#
# Statistics by Class:
#
#                      Class: Control Class: PRAD Class: NSCLC Class: SKCM
# Sensitivity                  0.7879      0.7344       0.6800     0.28571
# Specificity                  0.8350      0.8857       0.9444     0.92258
# Pos Pred Value               0.7536      0.7966       0.6800     0.25000
# Neg Pred Value               0.8600      0.8455       0.9444     0.93464
# Prevalence                   0.3905      0.3787       0.1479     0.08284
# Detection Rate               0.3077      0.2781       0.1006     0.02367
# Detection Prevalence         0.4083      0.3491       0.1479     0.09467
# Balanced Accuracy            0.8114      0.8100       0.8122     0.60415

# %%
# %%R
# DTH3 <- loocvDTs(snmData = snmShogundataPSUniqueDecontamDPQC,
#                  samplingSize = 69,
#                  DTs = c("Control","PRAD","NSCLC"),
#                  caretTuneGrid = defaultGBMGrid)
# Out:
# [1] "Iteration: 1/153"
# [1] "Iteration: 2/153"
# [1] "Iteration: 3/153"
# [1] "Iteration: 4/153"
# [1] "Iteration: 5/153"
# [1] "Iteration: 6/153"
# [1] "Iteration: 101/153"
# [1] "Iteration: 102/153"
# [1] "Iteration: 103/153"
# [1] "Iteration: 104/153"
# [1] "Iteration: 105/153"
# [1] "Iteration: 106/153"
# [1] "Iteration: 107/153"
# [1] "Iteration: 108/153"
# [1] "Iteration: 109/153"
# [1] "Iteration: 110/153"
# [1] "Iteration: 111/153"
# [1] "Iteration: 112/153"
# [1] "Iteration: 113/153"
# [1] "Iteration: 114/153"
# [1] "Iteration: 115/153"
# [1] "Iteration: 116/153"
# [1] "Iteration: 117/153"
# [1] "Iteration: 118/153"
# [1] "Iteration: 119/153"
# [1] "Iteration: 120/153"
# [1] "Iteration: 121/153"
# [1] "Iteration: 122/153"
# [1] "Iteration: 123/153"
# [1] "Iteration: 124/153"
# [1] "Iteration: 125/153"
# [1] "Iteration: 126/153"
# [1] "Iteration: 127/153"
# [1] "Iteration: 128/153"
# [1] "Iteration: 129/153"
# [1] "Iteration: 130/153"
# [1] "Iteration: 131/153"
# [1] "Iteration: 132/153"
# [1] "Iteration: 133/153"
# [1] "Iteration: 134/153"
# [1] "Iteration: 135/153"
# [1] "Iteration: 136/153"
# [1] "Iteration: 137/153"
# [1] "Iteration: 138/153"
# [1] "Iteration: 139/153"
# [1] "Iteration: 140/153"
# [1] "Iteration: 141/153"
# [1] "Iteration: 142/153"
# [1] "Iteration: 143/153"
# [1] "Iteration: 144/153"
# [1] "Iteration: 145/153"
# [1] "Iteration: 146/153"
# [1] "Iteration: 147/153"
# [1] "Iteration: 148/153"
# [1] "Iteration: 149/153"
# [1] "Iteration: 150/153"
# [1] "Iteration: 151/153"
# [1] "Iteration: 152/153"
# [1] "Iteration: 153/153"
#                logLoss                    AUC                  prAUC
#              0.5527885              0.9008994              0.7836442
#               Accuracy                  Kappa                Mean_F1
#              0.7516340              0.5990345              0.7184257
#       Mean_Sensitivity       Mean_Specificity    Mean_Pos_Pred_Value
#              0.7147106              0.8681400              0.7274496
#    Mean_Neg_Pred_Value         Mean_Precision            Mean_Recall
#              0.8698315              0.7274496              0.7147106
#    Mean_Detection_Rate Mean_Balanced_Accuracy
#              0.2505447              0.7914253
# Confusion Matrix and Statistics
#
#           Reference
# Prediction Control PRAD NSCLC
#    Control      52   11     6
#    PRAD          8   49     2
#    NSCLC         3    8    14
#
# Overall Statistics
#
#                Accuracy : 0.7516
#                  95% CI : (0.6754, 0.8179)
#     No Information Rate : 0.4444
#     P-Value [Acc > NIR] : 1.113e-14
#
#                   Kappa : 0.599
#  Mcnemar's Test P-Value : 0.1665
#
# Statistics by Class:
#
#                      Class: Control Class: PRAD Class: NSCLC
# Sensitivity                  0.8254      0.7206       0.6364
# Specificity                  0.8111      0.8824       0.9160
# Pos Pred Value               0.7536      0.8305       0.5600
# Neg Pred Value               0.8690      0.7979       0.9375
# Prevalence                   0.4118      0.4444       0.1438
# Detection Rate               0.3399      0.3203       0.0915
# Detection Prevalence         0.4510      0.3856       0.1634
# Balanced Accuracy            0.8183      0.8015       0.7762
